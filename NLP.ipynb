# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Read the Data

# %%
import pandas as pd
import re

import warnings
warnings.filterwarnings('ignore')

# %%
column=['target','ids','date','flag','user','text']

# %%
path ='/content/drive/MyDrive/AI/NLP/twitter.csv'
df = pd.read_csv(path,encoding='ISO-8859-1',names=column)
df.head()
# Out:
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
df.tail(1)
# Out:
#          target         ids                          date      flag  \
# 1599999       4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                    user                                               text
# 1599999  RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...

# %%
dataset = df[['text','target']]

# %%
dataset.head()
# Out:
#                                                 text  target
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...       0
# 1  is upset that he can't update his Facebook by ...       0
# 2  @Kenichan I dived many times for the ball. Man...       0
# 3    my whole body feels itchy and like its on fire        0
# 4  @nationwideclass no, it's not behaving at all....       0

# %%
dataset.target.unique()
# Out:
# array([0, 4])

# %%
dataset['target'] = dataset['target'].replace(4,1)
dataset.target.unique()
# Out:
# array([0, 1])

# %%
dataset.isna().sum()
# Out:
# text      0
# target    0
# dtype: int64

# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# ## 1.Remove URL

# %%
str(dataset['text'][0])
# Out:
# "@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D"

# %%
pattern = re.compile(r'http[s]?:\/\/\S+')
pattern.sub('',str(dataset['text'][0]))
# Out:
# "@switchfoot  - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D"

# %%
def remove_url(text):
  pattern = re.compile(r'http[s]?:\/\/\S+')
  return pattern.sub('',text)

# %%
dataset['text'] = dataset['text'].apply(lambda x: remove_url(x))

# %%
dataset['text'].head()
# Out:
# 0    @switchfoot  - Awww, that's a bummer.  You sho...
# 1    is upset that he can't update his Facebook by ...
# 2    @Kenichan I dived many times for the ball. Man...
# 3      my whole body feels itchy and like its on fire
# 4    @nationwideclass no, it's not behaving at all....
# Name: text, dtype: object

# %% [markdown]
# ## 2.Remove HTML Tags

# %%
def remove_tag(text):
  pattern = re.compile(r'<.*?>')
  return pattern.sub('',text)

# %%
dataset['text'] = dataset['text'].apply(lambda x: remove_tag(x))

# %%
dataset['text'].head()
# Out:
# 0    @switchfoot  - Awww, that's a bummer.  You sho...
# 1    is upset that he can't update his Facebook by ...
# 2    @Kenichan I dived many times for the ball. Man...
# 3      my whole body feels itchy and like its on fire
# 4    @nationwideclass no, it's not behaving at all....
# Name: text, dtype: object

# %% [markdown]
# ## 3.Handling Emoticons

# %%
# Emojis
emojis = {':)': 'smile', ':-)': 'smile', ';d': 'wink', ':-E': 'vampire', ':(': 'sad',
          ':-(': 'sad', ':-<': 'sad', ':P': 'raspberry', ':O': 'surprised',
          ':-@': 'shocked', ':@': 'shocked',':-$': 'confused', ':\\': 'annoyed',
          ':#': 'mute', ':X': 'mute', ':^)': 'smile', ':-&': 'confused', '$_$': 'greedy',
          '@@': 'eyeroll', ':-!': 'confused', ':-D': 'smile', ':-0': 'yell', 'O.o': 'confused',
          '<(-_-)>': 'robot', 'd[-_-]b': 'dj', ":'-)": 'sadsmile', ';)': 'wink',
          ';-)': 'wink', 'O:-)': 'angel','O*-)': 'angel','(:-D': 'gossip', '=^.^=': 'cat',';D':'laughing'}

# %%
def remove_emoticons(text):
  for emoji in emojis:
    text = text.replace(emoji, "Emoji" + emojis[emoji])
  return text

# %%
dataset['text'] = dataset['text'].apply(lambda x: remove_emoticons(x))

# %%
! pip install emoji
# Out:
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (2.14.0)

# %%
import emoji

def remove_emoji(text):
  return emoji.demojize(text)

# %%
dataset['text'] = dataset['text'].apply(lambda x: remove_emoji(x))

# %%
text = 'Face with Hearts emoji 🥰 is often used to celebrate Valentine'
remove_emoji(text)
# Out:
# 'Face with Hearts emoji :smiling_face_with_hearts: is often used to celebrate Valentine'

# %% [markdown]
# ## 4.Handling User Names

# %%
def handle_username(text):
  pattern = re.compile(r'@[^\s]+')
  text = pattern.sub('Tuser',text)
  return text

# %%
dataset['text'] = dataset['text'].apply(lambda x: handle_username(x))

# %%
dataset['text'].head()
# Out:
# 0    Tuser  - Awww, that's a bummer.  You shoulda g...
# 1    is upset that he can't update his Facebook by ...
# 2    Tuser I dived many times for the ball. Managed...
# 3      my whole body feels itchy and like its on fire
# 4    Tuser no, it's not behaving at all. i'm mad. w...
# Name: text, dtype: object

# %% [markdown]
# ## 5.Remove Punctuation

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
punc = string.punctuation
def remove_punc(text):
  return text.translate(str.maketrans('','',punc))

# %%
dataset['text'] = dataset['text'].apply(lambda x: remove_punc(x))

# %%
remove_punc('Hi !, how are you?')
# Out:
# 'Hi  how are you'

# %% [markdown]
# ## 6.Remove Chat words or Slang Words

# %%
slang = '/content/drive/MyDrive/AI/NLP/slang.txt'

# %%
slang
# Out:
# '/content/drive/MyDrive/AI/NLP/slang.txt'

# %%
with open(slang,'r') as f:
  lines = f.readlines()

# %%
lines[0]
# Out:
# 'AFAIK=As Far As I Know\n'

# %%
lines[0].split('=')
# Out:
# ['AFAIK', 'As Far As I Know\n']

# %%
lines[0].split('=')[0]
# Out:
# 'AFAIK'

# %%
lines[0].split('=')[1][:-1]
# Out:
# 'As Far As I Know'

# %%
slang_dict = {}
for i in range(len(lines)):
  slang_dict[lines[i].split('=')[0]] = lines[i].split('=')[1][:-1]

# %%
slang_dict
# Out:
# {'AFAIK': 'As Far As I Know',
#  'AFK': 'Away From Keyboard',
#  'ASAP': 'As Soon As Possible',
#  'ATK': 'At The Keyboard',
#  'ATM': 'At The Moment',
#  'A3': 'Anytime, Anywhere, Anyplace',
#  'BAK': 'Back At Keyboard',
#  'BBL': 'Be Back Later',
#  'BBS': 'Be Back Soon',
#  'BFN': 'Bye For Now',
#  'B4N': 'Bye For Now',
#  'BRB': 'Be Right Back',
#  'BRT': 'Be Right There',
#  'BTW': 'By The Way',
#  'B4': 'Before',
#  'CU': 'See You',
#  'CUL8R': 'See You Later',
#  'CYA': 'See You',
#  'FAQ': 'Frequently Asked Questions',
#  'FC': 'Fingers Crossed',
#  'FWIW': "For What It's Worth",
#  'FYI': 'For Your Information',
#  'GAL': 'Get A Life',
#  'GG': 'Good Game',
#  'GN': 'Good Night',
#  'GMTA': 'Great Minds Think Alike',
#  'GR8': 'Great!',
#  'G9': 'Genius',
#  'IC': 'I See',
#  'ICQ': 'I Seek you (also a chat program)',
#  'ILU': 'ILU: I Love You',
#  'IMHO': 'In My Honest/Humble Opinion',
#  'IMO': 'In My Opinion',
#  'IOW': 'In Other Words',
#  'IRL': 'In Real Life',
#  'KISS': 'Keep It Simple, Stupid',
#  'LDR': 'Long Distance Relationship',
#  'LMAO': 'Laughing my a** off',
#  'LOL': 'Laughing out loud',
#  'LTNS': 'Long Time No See',
#  'L8R': 'Later',
#  'MTE': 'My Thoughts Exactly',
#  'M8': 'Mate',
#  'NRN': 'No Reply Necessary',
#  'OIC': 'Oh I See',
#  'PITA': 'Pain In The A..',
#  'PRT': 'Party',
#  'PRW': 'Parents Are Watching',
#  'QPSA?': 'Que Pasa?',
#  'ROFL': 'Rolling On The Floor Laughing',
#  'ROFLOL': 'Rolling On The Floor Laughing Out Loud',
#  'ROTFLMAO': 'Rolling On The Floor Laughing My A.. Off',
#  'SK8': 'Skate',
#  'STATS': 'Your sex and age',
#  'ASL': 'Age, Sex, Location',
#  'THX': 'Thank You',
#  'TTFN': 'Ta-Ta For Now!',
#  'TTYL': 'Talk To You Later',
#  'U': 'You',
#  'U2': 'You Too',
#  'U4E': 'Yours For Ever',
#  'WB': 'Welcome Back',
#  'WTF': 'What The F...',
#  'WTG': 'Way To Go!',
#  'WUF': 'Where Are You From?',
#  'W8': 'Wait...',
#  '7K': 'Sick:-D Laugher',
#  'TFW': 'That feeling when. TFW internet slang often goes in a caption to an image.',
#  'MFW': 'My face when',
#  'MRW': 'My reaction when',
#  'IFYP': 'I feel your pain',
#  'TNTL': 'Trying not to laugh',
#  'JK': 'Just kidding',
#  'IDC': 'I don’t care',
#  'ILY': 'I love you',
#  'IMU': 'I miss you',
#  'ADIH': 'Another day in hell',
#  'ZZZ': 'Sleeping, bored, tired',
#  'WYWH': 'Wish you were here',
#  'TIME': 'Tears in my eyes',
#  'BAE': 'Before anyone else',
#  'FIMH': 'Forever in my heart',
#  'BSAAW': 'Big smile and a wink',
#  'BWL': 'Bursting with laughter',
#  'BFF': 'Best friends forever',
#  'CSL': 'Can’t stop laughing'}

# %%
def remove_chatwords(text):
  new_text = []
  for w in text.split():
    if w.upper() in slang_dict:
      new_text.append(slang_dict[w.upper()])
    else:
      new_text.append(w)
  return " ".join(new_text)

# %%
remove_chatwords('rofl ! This is so funny')
# Out:
# 'Rolling On The Floor Laughing ! This is so funny'

# %%
dataset['text'] = dataset['text'].apply(lambda x: remove_chatwords(x))

# %% [markdown]
# ## 7.Convert into lower case

# %%
dataset['text'] = dataset['text'].str.lower()

# %% [markdown]
# ## 8.Spelling Correction

# %%
! pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.8->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.8->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.8->textblob) (4.66.6)

# %%
from textblob import TextBlob

str(TextBlob('I Luve Honey').correct())
# Out:
# 'I Have Money'

# %%
text = 'I Luve Honey'
tl = text.split()

# %%
# " ".join([str(TextBlob(i).correct()) for i in text.tl()])

# %%
! pip install autocorrect
# Out:
# Requirement already satisfied: autocorrect in /usr/local/lib/python3.10/dist-packages (2.6.1)

# %%
from autocorrect import Speller
spell = Speller(lang='en')
print([spell(i) for i in tl])
# Out:
# ['I', 'Live', 'Honey']

# %%
! pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.10/dist-packages (0.8.1)

# %%
from spellchecker import SpellChecker

# %%
def spell_crorect(text):
  tl = text.split()
  spell = SpellChecker()
  misspelled = spell.unknown(tl)
  return " ".join([spell.correction(i) for i in tl])

# %%
spell_crorect("Thes is not my shurt")
# Out:
# 'the is not my hurt'

# %% [markdown]
# Note: Since none of the spell correcting module working properly therefore we are not applying it on our datset

# %% [markdown]
# ## 9.Tokennization

# %%
! pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
word_tokenize('Hi! How are you?')
# Out:
# ['Hi', '!', 'How', 'are', 'you', '?']

# %%
def word_token(text):
  return word_tokenize(text)

# %%
dataset_copy = dataset.copy()

# %%
dataset_copy.head()
# Out:
#                                                 text  target
# 0  tuser awww thats a bummer you shoulda got davi...       0
# 1  is upset that he cant update his facebook by t...       0
# 2  tuser i dived many times for the ball managed ...       0
# 3     my whole body feels itchy and like its on fire       0
# 4  tuser no its not behaving at all im mad why am...       0

# %%
dataset['text'] = dataset['text'].apply(lambda x: word_token(x))

# %% [markdown]
# ## 10.Remove Stop Word

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
print(len(stopwords.words('english')))
# Out:
# 179

# %%
print(stopwords.fileids())
# Out:
# ['arabic', 'azerbaijani', 'basque', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']

# %%
stop_w = stopwords.words('english')

text_list = word_tokenize('i love pizza')
clean_text = [word for word in text_list if word not in stop_w]
clean_text
# Out:
# ['love', 'pizza']

# %%
from functools import lru_cache

@lru_cache(maxsize=50000)
def remove_stopwords(text):
  stop_w = stopwords.words('english')
  text_list = text.split()
  clean_text = [word for word in text_list if word not in stop_w]
  return clean_text

# %%
remove_stopwords('i love pizza')
# Out:
# ['love', 'pizza']

# %%
dataset = dataset_copy.copy()

# %%
dataset.head()
# Out:
#                                                 text  target
# 0  tuser awww thats a bummer you shoulda got davi...       0
# 1  is upset that he cant update his facebook by t...       0
# 2  tuser i dived many times for the ball managed ...       0
# 3     my whole body feels itchy and like its on fire       0
# 4  tuser no its not behaving at all im mad why am...       0

# %%
dataset['text'] = dataset['text'].apply(lambda x: remove_stopwords(x))

# %%
len(dataset['text'][0])
# Out:
# 11

# %%
len(dataset_copy['text'][0])
# Out:
# 88

# %% [markdown]
# ## 11.Stemming

# %%
from nltk.stem.porter import PorterStemmer

# %%
st=PorterStemmer()
stem = lru_cache(maxsize=50000)(st.stem)

def stemming_on_data(list_words):
  text = [stem(word) for word in list_words]
  return text

# %%
dataset['text'] = dataset['text'].apply(lambda x: stemming_on_data(x))

# %%
dataset.head()
# Out:
#                                                 text  target
# 0  [tuser, awww, that, bummer, shoulda, got, davi...       0
# 1  [upset, cant, updat, facebook, text, might, cr...       0
# 2  [tuser, dive, mani, time, ball, manag, save, 5...       0
# 3             [whole, bodi, feel, itchi, like, fire]       0
# 4                 [tuser, behav, im, mad, cant, see]       0

# %% [markdown]
# ## 12.Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
def list_tosent(list_words):
  return " ".join(list_words)

  list_tosent(dataset['text'][0])

# %%
dataset['text'] = dataset['text'].apply(lambda x: list_tosent(x))

# %%
dataset.head()
# Out:
#                                                 text  target
# 0  tuser awww that bummer shoulda got david carr ...       0
# 1  upset cant updat facebook text might cri resul...       0
# 2  tuser dive mani time ball manag save 50 rest g...       0
# 3                    whole bodi feel itchi like fire       0
# 4                        tuser behav im mad cant see       0

# %%
lm = WordNetLemmatizer()

@lru_cache(maxsize=50000)
def lemmatization_on_data(list_words):
  list_words = list_words.split()
  text = [lm.lemmatize(word) for word in list_words]
  return text

# %%
dataset['text'] = dataset['text'].apply(lambda x: lemmatization_on_data(x))

# %%
new_dataset = dataset.copy()

# %%
dataset['text'] = dataset['text'].apply(lambda x: list_tosent(x))

# %%
dataset.head()
# Out:
#                                                 text  target
# 0  tuser awww that bummer shoulda got david carr ...       0
# 1  upset cant updat facebook text might cri resul...       0
# 2  tuser dive mani time ball manag save 50 rest g...       0
# 3                    whole bodi feel itchi like fire       0
# 4                        tuser behav im mad cant see       0

# %% [markdown]
# ## 13.Vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split
# 497199 yep want
# 497200 yep wasnt
# 497201 yep watch
# 497202 yep week
# 497203 yep went
# 497204 yep wish
# 497205 yep wonder
# 497206 yep work
# 497207 yep year
# 497208 yep yep
# 497209 yep yep yep
# 497210 yeph
# 497211 yepi
# 497212 yepit
# 497213 yepp
# 497214 yepp im
# 497215 yepper
# 497216 yeppi
# 497217 yeppp
# 497218 yepthat
# 497219 yepyep
# 497220 yer
# 497221 yer day
# 497222 yer feel
# 497223 yer hous
# 497224 yer im
# 497225 yer mom
# 497226 yer ok
# 497227 yer think
# 497228 yer tweet
# 497229 yer welcom
# 497230 yerba
# 497231 yerp
# 497232 yerr
# 497233 yerrr
# 497234 yerrrr
# 497235 yerself
# 497236 yersterday
# 497237 yes
# 497238 yes amp
# 497239 yes best
# 497240 yes big
# 497241 yes diver
# 497242 yes dont
# 497243 yes exactli
# 497244 yes final
# 497245 yes finish
# 497246 yes good
# 497247 yes got
# 497248 yes gotta
# 497249 yes haha
# 497250 yes happi
# 497251 yes hope
# 497252 yes ill
# 497253 yes im
# 497254 yes im excit
# 497255 yes know
# 497256 yes laugh
# 497257 yes laugh loud
# 497258 yes let
# 497259 yes like
# 497260 yes love
# 497261 yes make
# 497262 yes man
# 497263 yes miss
# 497264 yes need
# 497265 yes plea
# 497266 yes realli
# 497267 yes sad
# 497268 yes tear
# 497269 yes tear eye
# 497270 yes thank
# 497271 yes think
# 497272 yes tuser
# 497273 yes wait
# 497274 yes watch
# 497275 yes work
# 497276 yes yes
# 497277 yes yes yes
# 497278 yesand
# 497279 yesbut
# 497280 yesh
# 497281 yesh im
# 497282 yesh yesh
# 497283 yeshhh
# 497284 yesi
# 497285 yesi know
# 497286 yesi love
# 497287 yesi think
# 497288 yesim
# 497289 yesit
# 497290 yesm
# 497291 yesno
# 497292 yesquot
# 497293 yessh
# 497294 yesshhh
# 497295 yessi
# 497296 yessir
# 497297 yesso
# 497298 yesssir
# 497299 yessum
# 497300 yest
# 497301 yestarday
# 497302 yesteday
# 497303 yester
# 497304 yesteray
# 497305 yesterday
# 497306 yesterday 10
# 497307 yesterday 2day
# 497308 yesterday actual
# 497309 yesterday afternoon
# 497310 yesterday ah
# 497311 yesterday alreadi
# 497312 yesterday amaz
# 497313 yesterday amp
# 497314 yesterday amp today
# 497315 yesterday anoth
# 497316 yesterday answer
# 497317 yesterday anyon
# 497318 yesterday appar
# 497319 yesterday appreci
# 497320 yesterday ask
# 497321 yesterday ate
# 497322 yesterday aw
# 497323 yesterday awesom
# 497324 yesterday bad
# 497325 yesterday bad day
# 497326 yesterday bbq
# 497327 yesterday bc
# 497328 yesterday beauti
# 497329 yesterday believ
# 497330 yesterday best
# 497331 yesterday best day
# 497332 yesterday bet
# 497333 yesterday better
# 497334 yesterday big
# 497335 yesterday birthday
# 497336 yesterday bit
# 497337 yesterday blast
# 497338 yesterday bodi
# 497339 yesterday boo
# 497340 yesterday bought
# 497341 yesterday bout
# 497342 yesterday bring
# 497343 yesterday busi
# 497344 yesterday buy
# 497345 yesterday came
# 497346 yesterday catch
# 497347 yesterday caus
# 497348 yesterday check
# 497349 yesterday clean
# 497350 yesterday cold
# 497351 yesterday come
# 497352 yesterday comput
# 497353 yesterday concert
# 497354 yesterday cool
# 497355 yesterday cri
# 497356 yesterday cute
# 497357 yesterday cuz
# 497358 yesterday dad
# 497359 yesterday dammit
# 497360 yesterday damn
# 497361 yesterday danc
# 497362 yesterday day
# 497363 yesterday definit
# 497364 yesterday didnt
# 497365 yesterday didnt tear
# 497366 yesterday doesnt
# 497367 yesterday dont
# 497368 yesterday dont know
# 497369 yesterday drive
# 497370 yesterday eat
# 497371 yesterday emojiwink
# 497372 yesterday end
# 497373 yesterday enjoy
# 497374 yesterday episod
# 497375 yesterday excit
# 497376 yesterday experi
# 497377 yesterday fail
# 497378 yesterday famili
# 497379 yesterday far
# 497380 yesterday feel
# 497381 yesterday feel bad
# 497382 yesterday feel good
# 497383 yesterday feel like
# 497384 yesterday felt
# 497385 yesterday final
# 497386 yesterday follow
# 497387 yesterday forgot
# 497388 yesterday friday
# 497389 yesterday friend
# 497390 yesterday fuck
# 497391 yesterday fun
# 497392 yesterday funni
# 497393 yesterday gave
# 497394 yesterday gig
# 497395 yesterday glad
# 497396 yesterday gone
# 497397 yesterday gonna
# 497398 yesterday good
# 497399 yesterday good day
# 497400 yesterday gorgeou
# 497401 yesterday got
# 497402 yesterday got home
# 497403 yesterday got shot
# 497404 yesterday gotta
# 497405 yesterday great
# 497406 yesterday great day
# 497407 yesterday guess
# 497408 yesterday guy
# 497409 yesterday ha
# 497410 yesterday haha
# 497411 yesterday half
# 497412 yesterday hand
# 497413 yesterday happen
# 497414 yesterday happi
# 497415 yesterday hate
# 497416 yesterday havent
# 497417 yesterday headach
# 497418 yesterday heard
# 497419 yesterday help
# 497420 yesterday hit
# 497421 yesterday hope
# 497422 yesterday hot
# 497423 yesterday hour
# 497424 yesterday hous
# 497425 yesterday hr
# 497426 yesterday hurt
# 497427 yesterday id
# 497428 yesterday ill
# 497429 yesterday im
# 497430 yesterday im gonna
# 497431 yesterday im good
# 497432 yesterday im sick
# 497433 yesterday instead
# 497434 yesterday internet
# 497435 yesterday isnt
# 497436 yesterday ive
# 497437 yesterday jump
# 497438 yesterday kinda
# 497439 yesterday knew
# 497440 yesterday know
# 497441 yesterday late
# 497442 yesterday laugh
# 497443 yesterday laugh loud
# 497444 yesterday leav
# 497445 yesterday left
# 497446 yesterday leg
# 497447 yesterday let
# 497448 yesterday like
# 497449 yesterday link
# 497450 yesterday littl
# 497451 yesterday live
# 497452 yesterday long
# 497453 yesterday long day
# 497454 yesterday look
# 497455 yesterday look forward
# 497456 yesterday look like
# 497457 yesterday lost
# 497458 yesterday lot
# 497459 yesterday lot fun
# 497460 yesterday love
# 497461 yesterday lt3
# 497462 yesterday lunch
# 497463 yesterday mail
# 497464 yesterday make
# 497465 yesterday man
# 497466 yesterday manag
# 497467 yesterday mani
# 497468 yesterday mayb
# 497469 yesterday mean
# 497470 yesterday meet
# 497471 yesterday mention
# 497472 yesterday mess
# 497473 yesterday met
# 497474 yesterday miss
# 497475 yesterday mom
# 497476 yesterday month
# 497477 yesterday morn
# 497478 yesterday movi
# 497479 yesterday muscl
# 497480 yesterday nearli
# 497481 yesterday need
# 497482 yesterday new
# 497483 yesterday nice
# 497484 yesterday night
# 497485 yesterday normal
# 497486 yesterday noth
# 497487 yesterday oh
# 497488 yesterday ok
# 497489 yesterday okay
# 497490 yesterday old
# 497491 yesterday omg
# 497492 yesterday open
# 497493 yesterday ouch
# 497494 yesterday pain
# 497495 yesterday park
# 497496 yesterday parti
# 497497 yesterday pay
# 497498 yesterday peopl
# 497499 yesterday perfect
# 497500 yesterday pick
# 497501 yesterday play
# 497502 yesterday plea
# 497503 yesterday poor
# 497504 yesterday post
# 497505 yesterday pretti
# 497506 yesterday pretti good
# 497507 yesterday probabl
# 497508 yesterday problem
# 497509 yesterday prom
# 497510 yesterday quit
# 497511 yesterday quoti
# 497512 yesterday quotsonni
# 497513 yesterday quotsonni chancequot
# 497514 yesterday rain
# 497515 yesterday read
# 497516 yesterday readi
# 497517 yesterday realli
# 497518 yesterday realli realli
# 497519 yesterday relax
# 497520 yesterday rememb
# 497521 yesterday right
# 497522 yesterday rip
# 497523 yesterday rock
# 497524 yesterday sad
# 497525 yesterday said
# 497526 yesterday sat
# 497527 yesterday save
# 497528 yesterday saw
# 497529 yesterday say
# 497530 yesterday school
# 497531 yesterday set
# 497532 yesterday shoot
# 497533 yesterday shop
# 497534 yesterday sick
# 497535 yesterday sigh
# 497536 yesterday silli
# 497537 yesterday sleep
# 497538 yesterday slept
# 497539 yesterday sold
# 497540 yesterday someon
# 497541 yesterday someth
# 497542 yesterday soo
# 497543 yesterday soon
# 497544 yesterday sooo
# 497545 yesterday soooo
# 497546 yesterday sore
# 497547 yesterday sorri
# 497548 yesterday sort
# 497549 yesterday sound
# 497550 yesterday spent
# 497551 yesterday start
# 497552 yesterday stay
# 497553 yesterday stop
# 497554 yesterday storm
# 497555 yesterday stuck
# 497556 yesterday stupid
# 497557 yesterday suck
# 497558 yesterday summer
# 497559 yesterday sun
# 497560 yesterday sunni
# 497561 yesterday super
# 497562 yesterday suppos
# 497563 yesterday sure
# 497564 yesterday taken
# 497565 yesterday talk
# 497566 yesterday tear
# 497567 yesterday tear eye
# 497568 yesterday tell
# 497569 yesterday thank
# 497570 yesterday thank god
# 497571 yesterday thing
# 497572 yesterday think
# 497573 yesterday think im
# 497574 yesterday tho
# 497575 yesterday thought
# 497576 yesterday till
# 497577 yesterday tire
# 497578 yesterday today
# 497579 yesterday today im
# 497580 yesterday told
# 497581 yesterday tomorrow
# 497582 yesterday took
# 497583 yesterday total
# 497584 yesterday tri
# 497585 yesterday turn
# 497586 yesterday tuser
# 497587 yesterday tuser tuser
# 497588 yesterday tweet
# 497589 yesterday twitter
# 497590 yesterday ugh
# 497591 yesterday unfortun
# 497592 yesterday visit
# 497593 yesterday wait
# 497594 yesterday wake
# 497595 yesterday walk
# 497596 yesterday wanna
# 497597 yesterday want
# 499936 ññ ð²ð
# 499937 ññ ðµ
# 499938 ññ ðµð
# 499939 ññ ðµñ
# 499940 ññ ðºð
# 499941 ññ ð½ð
# 499942 ññ ð½ð¾
# 499943 ññ ð½ñ
# 499944 ññ ð¾
# 499945 ññ ð¾ ð½ð
# 499946 ññ ð¾ ð¾ññ
# 499947 ññ ð¾ð
# 499948 ññ ð¾ð ðºð¾
# 499949 ññ ð¾ð¼
# 499950 ññ ð¾ñ
# 499951 ññ ññ
# 499952 ññð½ð¾
# 499953 ñññ
# 499954 øcopyright
# 499955 øcopyright øªù
# 499956 øcopyright ø³ø
# 499957 øcopyright ø³ù
# 499958 øregisteredø
# 499959 øregisteredøµù
# 499960 øregisteredù
# 499961 øª
# 499962 øª øcopyright
# 499963 øª øªø
# 499964 øª øªø øª
# 499965 øªø
# 499966 øªø øª
# 499967 øªø øªù
# 499968 øªø¹ø
# 499969 øªø¹ù
# 499970 øªù
# 499971 øªù øªø
# 499972 øªù ø³
# 499973 øªù ø³ù
# 499974 øªù ø¹ù
# 499975 øªù ùù
# 499976 ø²
# 499977 ø²ø
# 499978 ø²ø øªø
# 499979 ø²ù
# 499980 ø³
# 499981 ø³ø
# 499982 ø³ø øcopyright
# 499983 ø³ù
# 499984 ø³ù ø¹ø
# 499985 ø³ù ùù
# 499986 øµø
# 499987 øµù
# 499988 ø¹
# 499989 ø¹ø
# 499990 ø¹ø øcopyright
# 499991 ø¹ù
# 499992 ø¹ù øªù
# 499993 ø¹ù ø¹ù
# 499994 øºù
# 499995 ùø
# 499996 ùø øcopyright
# 499997 ùù
# 499998 ùù øcopyright
# 499999 úcopyrightø

# %% [markdown]
# ## 14.Apply algorithm and predict the sentiment

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

nb_model = MultinomialNB()
nb_model.fit(X_train_tfidf, y_train)

y_pred = nb_model.predict(X_test_tfidf)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7732625

# %% [markdown]
# ## 15. Prediction

# %%
def sentiment(list_of_tweets):
  new_tweet = tfidf.transform(list_of_tweets)
  if nb_model.predict(new_tweet)==1:
    return 'Happy'

  else:
    return 'Unhappy'

# %%
new_tweet=['i am sad']
sentiment(new_tweet)
# Out:
# 'Unhappy'

# %% [markdown]
# # Sentiment Analysis with RNN

# %%
dataset.head()
# Out:
#                                                 text  target
# 0  tuser awww that bummer shoulda got david carr ...       0
# 1  upset cant updat facebook text might cri resul...       0
# 2  tuser dive mani time ball manag save 50 rest g...       0
# 3                    whole bodi feel itchi like fire       0
# 4                        tuser behav im mad cant see       0

# %%
words=set()

for data in new_dataset['text']:
  for word in data:
    words.add(word)

# %%
number_of_words = len(words)
number_of_words
# Out:
# 396196

# %%
new_dataset['text'] = new_dataset['text'].apply(lambda x: list_tosent(x))

# %%
new_dataset.to_csv('/content/drive/MyDrive/AI/NLP/sentiment_analysis.csv', index = False)

# %% [markdown]
# ## 1.Import Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
max_features = 396196

# %% [markdown]
# ## 2.Read the Data

# %%
new_dataset = pd.read_csv('/content/drive/MyDrive/AI/NLP/sentiment_analysis.csv')

# %%
new_dataset.head(1)
# Out:
#                                                 text  target
# 0  tuser awww that bummer shoulda got david carr ...       0

# %%
new_dataset['text'] = new_dataset['text'].astype('str')

# %%
(new_dataset['text'].head())
# Out:
# 0    tuser awww that bummer shoulda got david carr ...
# 1    upset cant updat facebook text might cri resul...
# 2    tuser dive mani time ball manag save 50 rest g...
# 3                      whole bodi feel itchi like fire
# 4                          tuser behav im mad cant see
# Name: text, dtype: object

# %%
new_dataset['text'].values
# Out:
# array(['tuser awww that bummer shoulda got david carr third day emojilaugh',
#        'upset cant updat facebook text might cri result school today also blah',
#        'tuser dive mani time ball manag save 50 rest go bound', ...,
#        'readi mojo makeov ask detail',
#        'happi 38th birthday boo alll tear eye tupac amaru shakur',
#        'happi charitytuesday tuser tuser tuser'], dtype=object)

# %% [markdown]
# ## 3.Tokenize with the index

# %%
tokenizer_keras = Tokenizer(num_words=max_features, split=' ')
tokenizer_keras.fit_on_texts(new_dataset['text'].values)
X = tokenizer_keras.texts_to_sequences(new_dataset['text'].values)
X
# Out:
# [[1, 385, 52, 1078, 3041, 15, 721, 7461, 1663, 5, 1820],
#  [607, 13, 228, 452, 372, 212, 243, 978, 84, 11, 195, 1073],
#  [1, 3658, 229, 249, 879, 711, 515, 1159, 360, 3, 2803],
#  [343, 668, 25, 2552, 8, 891],
#  [1, 4071, 2, 470, 13, 24],
#  [1, 343, 1936],
#  [32, 401],
#  [1, 91, 101, 17, 14, 24, 97, 105, 176, 176, 12, 21, 2, 435, 16, 685],
#  [1, 687, 62],
#  [1, 2125, 114911],
#  [1308, 346, 2634, 489, 1428],
#  [16535, 794],
#  [1, 327, 1318, 31, 154, 12488, 1380, 2822],
#  [1, 776, 741, 389, 99, 123, 324],
#  [1, 2003, 106, 62, 2372, 27, 73, 3543, 25177, 114912],
#  [1, 48, 15, 31, 20, 1, 2089],
#  [2448, 929, 1608, 139, 1452, 31, 651, 25178, 4510, 456],
#  [1246, 2285],
#  [1, 597, 74, 127, 19, 24, 1537, 9, 3172],
#  [1, 40, 522, 281, 2328, 1465, 281],
#  [1, 5, 62, 4, 42, 125],
#  [22, 65, 119, 302, 222, 3251, 3173, 7194, 74, 17, 14, 529],
#  [1, 1270, 643, 573],
#  [59, 3, 29],
#  [30555, 294, 467, 47],
#  [76, 119, 321, 83],
#  [3, 243, 51, 31, 3018],
#  [2, 55, 114913],
#  [2804, 12, 21, 7281, 116, 121, 7281, 121, 4, 470],
#  [1805, 270, 2177, 727, 912, 4, 625, 319, 17, 14],
#  [3686, 1950, 534, 1633, 34, 35, 22],
#  [1, 19, 3, 1903, 1816, 6279, 73811, 466, 253, 391, 3, 22, 8814, 253, 73],
#  [154, 51, 1405, 47, 549, 8178, 45, 7, 474],
#  [1, 1597, 9, 197, 20],
#  [1, 243, 2515, 14, 51, 30],
#  [116, 2, 112, 667, 86, 299, 432, 287, 112, 803, 3222, 18, 2873, 8, 4272, 79],
#  [1, 50, 161, 205, 492, 187, 6, 5, 50, 1496, 8, 608, 86],
#  [1, 67, 79, 17, 14, 344, 41156],
#  [1, 10, 389, 625, 10, 26, 77, 19, 23, 189, 4511],
#  [79,
#   294,
#   17502,
#   7,
#   8667,
#   562,
#   2198,
#   412,
#   294,
#   11753,
#   130,
#   5,
#   52,
#   72,
#   580,
#   20,
#   1313],
#  [27, 10, 25, 8, 4, 11, 15, 268, 47, 817, 209],
#  [217, 465, 11754, 860, 22, 316, 346, 395],
#  [55, 55, 55, 10, 23, 76, 25, 107, 51, 33, 13],
#  [1, 385, 399, 48, 24, 92, 1721, 2, 55, 20],
#  [409, 462, 411, 5702, 120, 668, 240, 55, 395, 346, 265],
#  [1, 146, 2, 61, 226, 195, 169, 480, 17, 14],
#  [177,
#   1621,
#   4823,
#   1022,
#   38,
#   8,
#   57059,
#   33,
#   194,
#   530,
#   33,
#   864,
#   325,
#   4055,
#   73812],
#  [40, 114914, 1491, 1, 1134, 494, 445, 222, 1095],
#  [1320, 55, 16102, 114915, 346],
#  [1, 40, 2, 67, 62, 26, 1309],
#  [4235, 262, 1556, 600, 877, 606, 114916, 33, 49, 4235],
#  [1, 192, 1185, 352, 253, 1837, 24, 65, 82, 87, 4193, 1110, 131],
#  [2270, 777, 70, 4413, 101, 6379],
#  [203, 659, 393, 431, 842, 390, 934, 725, 555, 305, 419],
#  [32, 401],
#  [1, 117, 3138, 42, 19, 10, 26, 2094, 160, 828, 10310, 67, 1490],
#  [1, 76, 194],
#  [55, 25, 1917, 3, 85, 231, 69, 73, 1191, 26, 85, 64, 94, 224, 159, 1115],
#  [114917, 1101, 47],
#  [244, 154, 129, 3309, 919, 865, 240, 193, 179, 2635, 28],
#  [1, 20, 2280, 6021, 47631, 89, 2210, 982, 3072],
#  [138, 512, 131, 7],
#  [111, 132],
#  [740, 73, 74, 99, 1232, 1002, 234, 114918, 3749, 99],
#  [71, 5, 63, 105, 39, 47, 1990],
#  [1, 63, 121, 232, 175, 226, 13, 77, 396, 137, 1004, 12, 460, 341, 4414],
#  [6312, 18, 84, 47],
#  [1395, 226, 330, 331, 564, 9044, 113, 7368, 10589, 86],
#  [1, 539, 24, 95],
#  [1, 469, 206, 17013, 7282, 5, 11],
#  [1,
#   40,
#   53,
#   436,
#   10,
#   27,
#   38,
#   644,
#   1245,
#   170,
#   69,
#   91,
#   630,
#   67,
#   2,
#   752,
#   32,
#   913],
#  [1, 2, 117, 87, 58, 32, 78, 7, 114919, 3923, 258],
#  [27, 76, 83, 5738, 585, 4470, 2202, 1399],
#  [562,
#   11580,
#   11,
#   10590,
#   23911,
#   11581,
#   114920,
#   616,
#   252,
#   2140,
#   4203,
#   672,
#   461,
#   216,
#   271,
#   120],
#  [121, 85, 1975],
#  [2074, 137, 783, 8, 14991],
#  [1,
#   6380,
#   5171,
#   583,
#   8731,
#   3068,
#   1754,
#   193,
#   24,
#   3293,
#   95,
#   526,
#   2067,
#   33,
#   13767],
#  [35, 3855, 68, 939],
#  [26, 880, 483, 1678],
#  [202, 170, 8, 42, 34, 3102, 2336, 73813, 625],
#  [51, 95, 76, 69, 495, 24, 47, 30],
#  [1, 15, 148, 5118, 6686, 27, 3334, 689, 129, 246, 1120, 303],
#  [1853, 408],
#  [1, 22749],
#  [172, 10, 8971, 28402, 2685],
#  [1040, 12293, 8815, 76, 295, 483, 604, 5, 4, 646],
#  [1, 91, 20, 205, 222, 4102, 1207],
#  [771, 139, 202, 20865, 257, 7, 4, 198, 1124],
#  [127, 964, 22],
#  [1, 67, 709, 1028, 543, 16, 375, 462, 58, 10197, 1412, 12],
#  [1, 1120, 1601, 745, 2347, 8055, 799, 294, 12489],
#  [814, 500, 10, 23, 41],
#  [261, 5949, 793],
#  [731, 104, 1935, 5640, 78, 7604, 57060, 178, 613, 191, 182, 2406, 33, 342],
#  [1, 657, 27, 143, 383, 4322, 26, 66, 114, 170, 57061],
#  [73814, 112, 102, 876],
#  [114921, 3, 1951, 182, 740, 220, 2857, 4865, 391, 376, 41, 42, 923, 28],
#  [91, 190, 22, 10198, 582, 63, 313, 22, 330],
#  [1, 10, 60, 389, 7],
#  [63, 552, 439, 610, 8595, 14047, 553, 552, 9595, 6],
#  [668, 20, 4680, 17014, 120, 240, 2579, 240, 2507, 20, 4680, 1689, 120],
#  [1, 29, 3301, 7283, 592, 221, 362, 15, 351, 3060, 748, 249, 41, 86],
#  [850, 294, 7],
#  [31, 19293],
#  [1, 340, 726, 633, 2701, 18, 17, 14, 968],
#  [1, 132, 394, 4899, 510, 431, 8519, 4997],
#  [2250, 193, 868, 125, 353, 35, 226, 20],
#  [64, 649, 106, 182, 307, 63, 493, 1216, 182, 307, 1037, 22, 17015, 110],
#  [1, 4916],
#  [1, 23, 411, 474, 202, 66, 8179, 850, 249],
#  [675, 79, 701],
#  [2, 336, 55, 356, 12727, 151, 21771],
#  [1, 67, 161, 13498, 30556, 27, 67],
#  [1, 62, 34, 1098, 4015, 66, 2016, 274, 190, 194],
#  [1, 29, 116],
#  [1, 172, 2796, 994, 3147, 17, 14, 10, 19, 198, 405, 8, 42, 9],
#  [1, 80, 341, 23, 10858, 803, 595],
#  [225, 13, 51, 11149],
#  [349, 36552, 107, 503, 13, 118],
#  [1, 7605, 20, 205, 2, 138, 8816, 47, 28403, 26, 254, 107, 3, 354, 325, 120],
#  [733, 283, 114922, 798, 1212],
#  [814, 500, 210, 10, 23, 41],
#  [23, 111, 1924, 3335, 154, 126, 5102, 153, 6],
#  [362, 18, 544, 139, 787, 243, 142, 351],
#  [185, 30, 2044, 820, 5854, 849, 2, 30557, 57062, 18, 47632, 76, 4, 112],
#  [1, 2, 180, 329, 9596, 1702],
#  [1,
#   2768,
#   13,
#   24,
#   2090,
#   248,
#   114923,
#   7,
#   3651,
#   13,
#   49,
#   263,
#   4,
#   7702,
#   134,
#   337,
#   41,
#   1393,
#   1935,
#   113,
#   449,
#   303],
#  [59, 236, 4, 652, 652, 1648, 42, 32, 42, 2, 190, 3, 4, 125],
#  [2, 242],
#  [1, 6457, 10, 199, 72, 70, 298, 1399, 47],
#  [1, 53, 21772, 33, 3, 85, 1416, 204],
#  [29, 771, 6412, 3, 160, 95],
#  [1, 785, 434, 230, 7, 47, 119, 4866, 60, 214],
#  [270, 1860],
#  [2, 20, 709, 101, 1368, 2, 61, 114924, 2, 103, 9, 1331, 57, 51, 29, 36553],
#  [114925],
#  [20, 4484, 655],
#  [1, 16, 98, 83, 23, 2, 55, 1092, 493, 15, 313, 190, 7504],
#  [2257, 20, 4360, 416, 3928, 210, 3475, 10199, 282, 300, 1380],
#  [1, 165, 52],
#  [740, 3, 79],
#  [1, 689, 179, 18665],
#  [1, 91, 2, 3260, 45],
#  [3741, 157, 988, 114926, 3228, 17503, 68, 322, 194, 540, 490, 174],
#  [2953, 232, 42, 11, 126, 139],
#  [1,
#   33,
#   188,
#   141,
#   114927,
#   1942,
#   4551,
#   515,
#   20014,
#   142,
#   243,
#   183,
#   657,
#   661,
#   246],
#  [3190, 23912, 247],
#  [207, 212, 4653, 1774, 121, 114, 257, 8, 59, 2, 374],
#  [3, 51, 29, 47, 75, 5],
#  [1, 12, 21, 48, 4704, 6280, 515, 183, 73, 442, 86, 187, 115, 321, 189],
#  [1, 824],
#  [10, 565, 27, 10],
#  [1254, 208, 430],
#  [135, 1783, 117, 208, 42, 56],
#  [1,
#   3544,
#   2593,
#   48,
#   2917,
#   272,
#   3544,
#   284,
#   573,
#   66,
#   3598,
#   5487,
#   180,
#   455,
#   2251,
#   1897],
#  [145, 7, 215],
#  [4, 112, 17, 14, 184, 481, 268, 6238],
#  [4, 4162, 4344, 362],
#  [73815, 523, 221, 3, 7],
#  [40, 15, 22750, 473, 641, 290, 62, 4, 5137, 7073, 73, 885, 214, 615, 40, 28],
#  [415, 8668, 1300, 282, 4, 3, 25, 155, 6, 415, 54, 73816, 175],
#  [410, 114928],
#  [25, 63],
#  [1, 76, 6739, 169, 453, 295, 358, 169],
#  [1, 97, 3493, 17504, 5248, 1152, 278],
#  [2, 407, 437, 1064, 30, 488, 5, 1208, 784, 752, 221],
#  [16, 3965, 2010],
#  [3, 84, 95, 13, 114, 257, 445, 946, 215],
#  [1, 968, 12, 21],
#  [1, 490, 1023, 101, 15, 945, 55, 5, 920],
#  [365, 1499, 11, 928],
#  [722, 7],
#  [1534, 533, 911, 556, 7413, 2148, 26, 548, 89, 398, 149, 1604],
#  [1, 307, 827, 695, 20, 2716, 61],
#  [10, 24, 180, 773, 639],
#  [1, 2, 67, 87, 3, 114929],
#  [1, 278, 54, 4976, 1081],
#  [2, 33, 1288, 115, 553, 2023, 553, 2023, 1178, 395, 12089],
#  [11, 549, 6, 1463, 66, 77, 13, 114],
#  [211, 65, 114930, 299, 1748, 114931, 182],
#  [1, 1210, 2, 607, 313, 31, 135, 563, 218, 122, 86, 384, 2, 499, 607],
#  [177, 3293],
#  [3505, 363, 364],
#  [527, 4681, 35, 487, 1096, 73817, 331, 39, 2, 850, 249, 5],
#  [259, 129, 2079, 378, 74, 3, 171, 1367, 11, 1192, 3142],
#  [31, 793, 34, 55],
#  [229, 1009, 152, 128, 694, 5, 253, 114, 5155],
#  [1, 20, 922, 50, 1068, 4498],
#  [1, 9, 830, 161, 83, 1127, 2, 22751, 830, 30558, 830, 227, 83],
#  [6022, 214, 33, 15, 22, 5, 2507, 383, 39],
#  [1531,
#   26651,
#   746,
#   171,
#   169,
#   13,
#   177,
#   35,
#   8732,
#   1969,
#   1888,
#   1908,
#   212,
#   1473,
#   572],
#  [1, 40],
#  [3929, 6, 88],
#  [1, 6281, 247, 114932, 430, 92, 93, 59, 1172, 128, 8817, 3535, 365, 703],
#  [1, 76, 1176, 114933, 88, 21773, 731, 114934, 28],
#  [62, 4, 296, 125, 11, 2, 1087],
#  [114935, 3],
#  [3, 51, 1279],
#  [374, 103, 234, 68],
#  [327, 4, 296, 125, 11, 2, 1087],
#  [226, 775, 5357, 11, 48, 241, 15, 122, 86, 51],
#  [1, 85, 4609, 54, 646, 4609, 114936],
#  [1, 27, 10, 26, 83, 1582, 54, 26, 3506, 1415, 265, 124, 212, 514],
#  [1, 87, 3, 356, 74, 348, 25179, 74, 49, 263, 22, 3261, 59, 299],
#  [1, 26, 148, 58, 317, 1825, 790],
#  [76, 24, 14047, 55],
#  [400, 668, 1452, 4273, 5703, 4917, 66, 1429, 1522],
#  [1, 2, 516, 60, 220, 62, 12, 21, 3, 976],
#  [1],
#  [1, 26, 19, 141, 246, 1283, 150],
#  [491, 5138, 229, 249, 11, 3, 2143, 1537],
#  [394, 101, 688, 85, 183, 2190, 223, 58, 225],
#  [1, 1374, 1374, 556, 441, 4, 1428, 814, 225],
#  [5676, 11150, 38, 55, 73818, 266, 7369, 26652, 73819, 8, 38, 35, 1469, 109],
#  [55, 525, 1532, 638],
#  [2, 72, 4, 185, 47, 73820, 72, 4, 5587, 5802, 57063, 55],
#  [2, 2138, 14992, 384, 1492, 13, 114, 170, 725, 2, 253, 1087],
#  [1232, 1197, 141, 82, 13, 4, 34, 534],
#  [1, 33229, 327, 1444, 444, 941, 17, 14],
#  [1, 29, 34, 9820, 85, 38, 6],
#  [1, 52, 83, 2672, 53, 327, 779, 10, 26, 280, 156, 142, 1909, 276, 53],
#  [1, 509, 264, 381, 3215, 393],
#  [1, 385, 6, 241, 4103, 104, 10, 7, 215, 29, 56, 35, 487, 72, 163, 614],
#  [1, 138, 4, 55],
#  [20, 44, 137, 449, 2, 94, 267, 3190, 137, 1964, 20, 2549, 137],
#  [737, 314, 151, 1048, 189, 554],
#  [114937,
#   78,
#   4072,
#   26653,
#   3123,
#   707,
#   4135,
#   6282,
#   117,
#   212,
#   832,
#   94,
#   133,
#   6168],
#  [4610, 3584, 377, 59],
#  [97, 97, 33, 57, 114, 280, 581, 114938],
#  [40, 476, 3294, 159, 105, 38, 297, 359, 5],
#  [33, 13, 114, 1113],
#  [1, 23, 58, 995, 3, 44],
#  [212, 4, 483, 604],
#  [1,
#   37,
#   550,
#   14353,
#   119,
#   73821,
#   1236,
#   1419,
#   598,
#   98,
#   19294,
#   166,
#   873,
#   304,
#   410,
#   373,
#   1332],
#  [1, 26, 32, 114, 75, 20015, 26, 114939, 3387, 553, 73822],
#  [1, 1717, 119, 114940, 2035, 136, 5535, 861, 5535, 17, 14, 288, 845],
#  [1830, 321, 57064],
#  [1, 19, 1606, 114941, 21774, 971, 69, 114942],
#  [2, 795, 115, 828, 2038, 2314, 1689],
#  [63, 5, 23913, 392],
#  [20, 13, 49, 676, 9938, 2124, 282, 90, 73],
#  [2, 27, 242, 10, 19, 3, 51, 152, 283, 186],
#  [1, 113, 547, 113, 3, 861],
#  [2024, 240, 1807, 121, 77, 310, 18, 2, 4036],
#  [1, 254, 23, 784, 8, 221, 7],
#  [1, 28404, 208, 2234],
#  [20, 8596, 3007, 585, 56, 1549, 10311, 73823],
#  [1, 261, 1035, 194, 89, 1861, 4236, 453, 73, 348, 788, 614],
#  [20, 100, 65, 539, 31, 37, 160, 704, 181, 1050, 2295],
#  [1],
#  [35, 238, 617, 10859],
#  [25, 175, 2245, 767, 189, 720, 114943, 273],
#  [172, 185, 953, 15701, 1364, 83, 270, 615, 6647, 7],
#  [20, 8596, 3007, 585, 56, 1549, 10311, 73823],
#  [26, 42, 575, 13, 285, 916, 42, 907, 15, 33, 26, 1453],
#  [175, 1014, 1984, 348],
#  [1,
#   10591,
#   114944,
#   24,
#   527,
#   10071,
#   5536,
#   4591,
#   26654,
#   406,
#   330,
#   213,
#   80,
#   7322,
#   36,
#   4163],
#  [33, 2193, 20016, 193, 25, 75, 76, 178, 112],
#  [213, 3, 18, 24],
#  [1, 36554, 406, 1976, 68, 9821, 2, 3, 79],
#  [1, 28, 1292, 204, 5194, 5194, 74, 125, 1292, 204],
#  [1, 261],
#  [124, 555, 2636, 2290, 36, 3811, 674],
#  [18056, 11917, 2133, 5322, 40, 107, 3, 63],
#  [70, 4611, 18],
#  [1, 509, 2, 264, 479, 48, 11012, 7],
#  [15331, 350, 2552],
#  [261, 2140, 114945, 2489, 7195, 19, 22, 19295],
#  [206, 240, 5702, 120, 1062, 4485, 213, 752],
#  [12965, 6211, 18],
#  [1, 997, 3403, 158, 77, 3, 41, 101, 9, 532],
#  [667, 197, 86, 1217, 14354, 1011, 114, 11, 508, 114946, 114947, 15702],
#  [1, 469, 4953, 10, 228, 283, 1061],
#  [1, 1027, 397, 2090, 3585, 17, 14, 390, 147, 18, 514, 397],
#  [1, 19296, 2, 1720, 52, 32, 268],
#  [188, 82, 970, 5, 234, 639, 68, 29, 440, 28, 30, 17, 14],
#  [1, 20, 11917],
#  [453, 32, 157, 226, 2009],
#  [724, 114948, 112, 211, 37, 608, 1598, 5, 7, 18, 508, 189],
#  [11423,
#   114949,
#   10,
#   565,
#   574,
#   28,
#   36555,
#   372,
#   7703,
#   2079,
#   673,
#   6,
#   114950,
#   4115],
#  [1, 10, 19, 156, 2115],
#  [336, 112, 1428, 1604],
#  [1],
#  [1, 150, 7, 329, 607],
#  [64,
#   8,
#   2058,
#   1810,
#   238,
#   159,
#   135,
#   1693,
#   82,
#   3,
#   11424,
#   1840,
#   73824,
#   95,
#   11424],
#  [1, 13, 486, 4, 18, 396, 904, 1088],
#  [1, 2, 450, 17, 14, 1226, 171, 47, 13, 138, 5487],
#  [15, 37, 31, 3409, 840, 4, 114964],
#  [40,
#   114965,
#   201,
#   110,
#   588,
#   294,
#   7,
#   889,
#   1749,
#   1705,
#   2,
#   157,
#   68,
#   114966,
#   1901,
#   821],
#  [1, 2762, 510, 897, 750],
#  [1, 29, 150, 43, 101, 25, 1685],
#  [1,
#   2530,
#   349,
#   5739,
#   26656,
#   72,
#   37,
#   20017,
#   1432,
#   1106,
#   34,
#   7,
#   2,
#   284,
#   559,
#   612,
#   113],
#  [1,
#   56,
#   36,
#   5983,
#   35,
#   14663,
#   1803,
#   41,
#   7323,
#   4,
#   41,
#   114967,
#   489,
#   12490,
#   36,
#   20867],
#  [1, 791, 465, 26, 1116, 6, 1099, 476, 2736, 1089, 109, 2089, 4751],
#  [1288, 870, 101, 74, 4, 1990, 99, 4, 1407, 145, 14, 139, 2768],
#  [1, 12295, 115, 269, 22, 1031, 4136, 2992, 3355, 1960, 59],
#  [1, 2938, 1977, 62, 24, 39],
#  [33, 112, 25, 176, 75, 15, 35, 2584, 29, 25, 6, 30, 51, 923, 441, 1428, 559],
#  [1, 26, 162, 4, 506, 86, 51, 2654, 823, 58, 148, 326, 103, 374],
#  [1, 16, 131, 421, 131, 35, 368, 62, 114, 38],
#  [48, 114968, 527, 13237, 114969, 260, 13237, 66, 5156, 2, 103],
#  [35, 20868, 416, 3361],
#  [1, 1185, 2122, 6413, 1420],
#  [267, 109, 31, 3117, 20869, 114970, 682],
#  [9, 1985],
#  [43, 22, 33, 125],
#  [498],
#  [10, 565, 66, 4, 829, 160, 62, 316, 17, 14, 2498, 19, 18, 8, 178],
#  [1558, 4156, 114971, 201, 379, 905, 7154, 13, 70, 324, 73828, 41157],
#  [1, 168, 290, 106, 17, 14, 539, 20, 42, 3, 3320, 550, 429, 1051],
#  [2655, 252, 474, 222, 378, 222, 378, 222, 3388, 5, 33, 3, 404, 898],
#  [1010, 130, 1308, 346, 132, 63, 7, 59, 40, 28, 330, 137, 123, 187, 15332],
#  [1, 2, 1150, 148, 352, 1292, 626, 390],
#  [25],
#  [1, 12, 21, 1737, 455, 1080, 167, 185, 30, 136, 133, 449],
#  [1, 254, 932, 8, 269, 652, 456, 346, 395],
#  [202, 1054, 175, 1574],
#  [192, 625, 66, 223, 553, 238, 665, 1188, 870, 488, 939],
#  [1, 69, 1912],
#  [1, 12, 460, 2, 67, 114972, 573],
#  [595, 114973, 1, 208, 21],
#  [17, 14, 244, 47636, 553, 964, 16105, 25180, 216, 3403, 4056, 710],
#  [168, 4471, 243],
#  [11, 118, 2, 72, 247, 300, 1117, 16106, 7235],
#  [114974,
#   419,
#   228,
#   1018,
#   114975,
#   209,
#   359,
#   413,
#   248,
#   49,
#   961,
#   785,
#   1577,
#   1404],
#  [1, 67, 2, 25, 358, 3239, 1990, 3, 39, 952],
#  [9, 28406, 1853, 129],
#  [19, 179, 1, 149, 751, 666],
#  [63,
#   377,
#   311,
#   1774,
#  [290, 102, 145, 638, 462, 49, 962, 180, 347, 4, 37, 261, 178, 20, 42, 11],
#  [976, 3, 20, 5589, 90],
#  [1295, 215],
#  [31, 1130, 11, 22752, 57071, 114986, 32, 2797],
#  [1760, 19, 115, 141, 121, 257, 174, 141],
#  [73833, 223],
#  [1, 441, 513],
#  [6780,
#   36,
#   12966,
#   1209,
#   19298,
#   26659,
#   513,
#   3244,
#   114987,
#   40,
#   114988,
#   111,
#   1780,
#   297,
#   2,
#   1322,
#   3599,
#   444],
#  [463, 32, 528],
#  [1, 80, 23, 593, 225, 3147],
#  [1, 2655, 148, 56],
#  [107, 3507, 355, 585],
#  [1, 52, 131, 11425, 642, 474],
#  [2, 193, 1804, 208, 365, 324, 22, 331, 85, 2, 55, 93, 114989, 545, 3456],
#  [13768, 342, 167, 25, 8, 463],
#  [1, 67],
#  [1, 10592, 1881],
#  [145, 369, 539],
#  [1, 24],
#  [505, 2213, 1841, 867, 70, 114990, 20019, 31, 793, 430, 2089, 300],
#  [15, 753, 125, 2134, 2969, 125, 2, 243, 59, 3202, 59],
#  [175, 8118],
#  [10, 8, 8520, 1340, 66, 78, 430, 201, 8, 147, 1103, 4217, 8],
#  [1, 48, 20020, 155, 6, 554, 296, 83],
#  [3, 153, 8181, 216, 991, 1578, 8906],
#  [1, 99, 1147, 397, 1365, 3157, 1957, 2, 47637, 1742, 75, 3239],
#  [17, 14, 7, 4, 112],
#  [1, 4451, 344, 10202, 4116, 840],
#  [1396, 32, 198, 255, 3276],
#  [1, 379, 462, 298, 510],
#  [929, 833, 111, 1233, 1202],
#  [26, 1, 175, 1574, 117, 29],
#  [416, 4472, 1313, 2107, 898, 22, 114991],
#  [1336, 159, 31, 68, 840, 92, 3, 79, 195, 211, 31, 430, 2089, 793],
#  [236, 41160, 590, 73834, 201, 854, 850],
#  [1, 3195, 47638, 33, 10, 22],
#  [20872, 641, 518, 733],
#  [1353, 32, 268],
#  [293, 337, 383, 1459, 114992, 13, 4],
#  [8521, 2775, 83, 34, 267, 583, 10, 23, 343, 492],
#  [1, 2, 67, 2667, 57072, 6570, 2, 55],
#  [82, 129, 251, 548, 20, 88, 68],
#  [13, 51, 350, 358, 2068, 10, 98, 2341, 66, 2569, 4, 706, 84, 47, 1017],
#  [1, 5829, 444, 1228, 1649, 2178, 295, 899, 2102, 216],
#  [547,
#   2439,
#   47639,
#   1594,
#   126,
#   139,
#   774,
#   1520,
#   910,
#   364,
#   2247,
#   4130,
#   251,
#   9711],
#  [1, 155, 42, 843],
#  [1, 303, 2, 114, 28, 215, 4, 779],
#  [6, 45, 140, 41, 3, 19, 41, 3, 18, 41, 79],
#  [76, 49, 961],
#  [5301, 1501, 1716, 518, 150, 1509, 71, 3, 2285, 119, 171, 30],
#  [12727, 169, 577, 134, 3, 194, 170, 55, 181, 151, 28, 125, 2, 33, 55],
#  [1, 341, 116, 114993],
#  [50, 13, 3, 1986],
#  [638, 462, 27, 62, 169, 5216],
#  [1, 91, 340, 17, 14, 94, 65, 245, 225, 3418, 112, 32, 51],
#  [593, 1429, 43, 30, 3103, 51, 2, 27, 103],
#  [2, 795, 115, 828, 2038, 2314, 35, 1327],
#  [1, 175, 1300, 115002, 115003, 84, 53],
#  [1, 80, 27, 625, 204, 8, 4],
#  [1, 383, 57073, 6119, 131, 11152, 3262],
#  [1, 91, 214, 1413, 72, 3, 33232, 671, 6, 1747, 276, 1546],
#  [225, 593, 183, 7803, 115004, 492, 1278, 3],
#  [1, 76, 41, 391, 2341, 19, 876, 399, 63, 74, 129, 154, 132, 305],
#  [45,
#   1106,
#   4323,
#   2282,
#   36,
#   160,
#   24,
#   1610,
#   29,
#   44,
#   75,
#   4071,
#   11,
#   43,
#   30,
#   13769],
#  [1, 20, 303],
#  [1, 67, 179, 1380, 229, 110, 278],
#  [1, 1854, 120, 1810],
#  [1, 3094],
#  [114, 27, 215, 94, 44],
#  [74, 407, 151, 201, 5],
#  [27, 55, 150, 27, 23],
#  [1],
#  [162, 22, 110, 50, 4, 2285, 862, 120, 309, 58],
#  [18, 7, 103, 331, 25, 242, 39],
#  [1, 1, 2290, 3457, 208, 39, 95, 316],
#  [1, 568, 14, 253, 14664, 115005, 14664, 571, 7197, 217, 275, 73],
#  [231, 1810, 343, 888, 15333, 405, 166, 22, 343, 1648, 7, 15, 1074],
#  [2, 140, 90, 129, 239],
#  [1,
#   2004,
#   115006,
#   2,
#   6649,
#   698,
#   15,
#   115007,
#   3992,
#   8,
#   73836,
#   902,
#   1230,
#   517,
#   333],
#  [5050, 51, 30, 27, 316, 17, 14],
#  [1, 13, 49, 57, 644, 2215, 49, 93, 90, 7916],
#  [20874, 70, 79, 2897],
#  [1, 2290, 3457, 208, 39, 95, 316],
#  [19, 243],
#  [32, 3, 1011, 47, 3, 449],
#  [2960, 1932, 3147, 608, 86, 160, 15704, 265],
#  [51, 707, 59, 39],
#  [1, 497, 7, 4933, 1950, 1272, 115008, 66, 1106],
#  [139, 1630, 3, 1181],
#  [1, 40, 2462, 711, 307, 134, 2730, 1248, 300, 785, 25, 205],
#  [175,
#   284,
#   1059,
#   10073,
#   13,
#   203,
#   533,
#   115009,
#   13,
#   3,
#   255,
#   13770,
#   980,
#   344,
#   647],
#  [34, 296],
#  [2347, 76, 725],
#  [659, 34, 25, 112],
#  [986, 251],
#  [168, 115010, 3457, 202, 4274, 20, 365, 1097, 111],
#  [1, 737, 366, 33233],
#  [1, 2, 117, 108, 892, 1107, 7198, 968, 1154, 2857, 28],
#  [9940, 2413, 103],
#  [10, 19, 321, 171, 47, 172, 7],
#  [157, 31, 109, 1278, 3458, 449, 395],
#  [1, 57074, 27, 593],
#  [1, 41, 203, 326, 11, 170, 948],
#  [1, 67, 179, 21776, 216, 68, 127, 3777, 4, 63, 41162, 30562],
#  [1, 4, 20021, 83, 1256, 115011, 1884, 339, 22, 5, 142, 1004, 808, 5282, 494],
#  [1, 923, 167, 12, 460, 2, 243, 58, 12, 21, 73837, 100],
#  [344, 18, 216, 369, 73838, 2746, 699, 33, 139, 1835],
#  [31, 5590, 207, 7, 115012, 215],
#  [5951, 564, 263, 37, 17, 14, 776, 1274, 429, 631, 518, 363, 17, 14, 4],
#  [1, 67, 179, 70, 366],
#  [1, 115013, 6, 1607, 5236, 41163, 42, 70, 160, 931],
#  [1, 6120, 1899, 10, 19, 4332],
#  [73837, 26, 1397, 33, 85, 225, 115014, 8378, 665, 1275, 523, 2148],
#  [1, 207, 48, 100, 241],
#  [76, 498, 126, 139, 63],
#  [15,
#   1841,
#   662,
#   2213,
#   19,
#   1077,
#   23915,
#   482,
#   86,
#   33,
#   122,
#   86,
#   3,
#   230,
#   75,
#   4,
#   29],
#  [1, 23, 102, 625, 573, 42, 43, 30, 3812, 11],
#  [28, 934, 135, 323, 1430, 7114, 73839, 175, 969, 1283, 251, 1577, 196],
#  [55, 5, 11153, 430],
#  [1, 261, 115015, 18668, 25184, 142, 364, 3, 73840, 23, 25],
#  [2, 336, 55, 58, 32, 401],
#  [19, 1024, 347, 37, 2, 374, 10, 77, 23, 29, 23, 42, 366],
#  [1, 15, 125, 31, 793, 9, 158, 93, 576, 2, 55, 43, 430],
#  [1, 254, 1978, 401],
#  [2, 103, 25, 8, 463, 223, 25, 8671, 34, 61, 3203, 4104, 2156],
#  [10, 19, 274, 2, 115016, 55],
#  [202, 73841],
#  [708, 2730, 673, 133, 20022],
#  [1, 382, 10, 94],
#  [1308, 346, 43, 22, 676],
#  [45, 2045, 218, 121, 78, 49, 57075],
#  [1, 155, 7324, 847, 1511, 28407, 283, 547, 2439, 21777, 265],
#  [115017, 18057, 1586, 610, 138, 286, 28, 20, 7, 29, 28, 93, 4998],
#  [1, 55, 23, 240, 668, 365, 223, 135, 873, 916, 205, 23],
#  [107, 355, 9308, 528, 7115, 1284, 3166],
#  [413, 178, 1365, 3556, 30, 106, 5, 18, 7, 98, 243, 2333],
#  [37,
#   20,
#   178,
#   252,
#   59,
#   909,
#   925,
#   690,
#   5,
#   88,
#   189,
#   1206,
#   1626,
#   612,
#   11919,
#   4612,
#   612,
#   30,
#   2857],
#  [1, 99, 240, 1652, 1147, 44, 66, 751, 440, 436, 490],
#  [1, 52, 593, 57076, 179],
#  [1,
#   13,
#   114,
#   69,
#   115018,
#   150,
#   115019,
#   841,
#   197,
#   57077,
#   240,
#   210,
#   2617,
#   236,
#   391,
#   4513,
#   3643],
#  [154, 64, 590],
#  [10074, 2984, 115020, 1948, 6781, 956, 3161, 155],
#  [48, 1308, 11920, 502, 2459, 36, 115021, 529, 30563],
#  [30564, 7649, 3262, 639, 208, 7, 46, 8, 32],
#  [1, 10, 8, 106, 109, 57078, 6121, 184],
#  [48, 6, 166, 2852, 39, 18, 2521, 3802, 2581, 1090, 8241, 25185, 55],
#  [25, 673, 6, 1552],
#  [15, 372, 1562],
#  [130, 5, 3104, 520, 17, 14, 171, 78, 165, 353, 3437, 3978],
#  [1149,
#   159,
#   409,
#   4204,
#   10075,
#   41,
#   3184,
#   122,
#   16537,
#   4613,
#   2947,
#   12731,
#   41,
#   32,
#   1730],
#  [1, 225, 52, 30565],
#  [1, 190, 343, 419, 92, 829, 172, 3993],
#  [82, 548, 3],
#  [157,
#   1231,
#   442,
#   43,
#   1372,
#   50,
#   20,
#   1148,
#   1762,
#   36560,
#   1148,
#   223,
#   10,
#   281,
#   133],
#  [73842, 46, 1130, 92, 59],
#  [1, 2, 707, 11013],
#  [195, 2080, 14357, 462, 86, 390],
#  [57, 486, 44, 115022, 65, 152, 399, 42, 24],
#  [8672,
#   1,
#   1267,
#   2196,
#   142,
#   38,
#   132,
#   2786,
#   81,
#   480,
#   2268,
#   212,
#   38,
#   63,
#   3232,
#   1045],
#  [19, 18, 423],
#  [1, 995, 94, 1798, 4, 1266, 50, 20, 123],
#  [1, 1405],
#  [1, 569, 22, 427, 313, 1904, 8598, 1994],
#  [1, 19, 22, 5561, 115023, 359],
#  [1, 341, 67, 179],
#  [285, 262, 557, 631, 475, 17, 14, 339, 246],
#  [1, 819],
#  [1, 24, 2978, 82, 1097, 626, 270, 4323, 115024, 28408],
#  [1, 1065, 188, 1186, 15705, 152],
#  [1, 348, 148, 82, 1051, 310, 18, 1301, 4, 2557, 15, 22, 352, 18, 1301],
#  [1, 2367, 57, 3, 51, 122, 86, 390],
#  [1, 2, 67, 179, 127, 55, 553, 363, 133, 9],
#  [13, 51, 2, 33, 1143, 8, 1062, 296],
#  [1, 40, 4016, 215, 1662, 127, 29, 166, 3505, 12493, 3, 51, 295, 1411, 401],
#  [1, 28, 27, 132, 386, 121, 2128],
#  [1, 2, 17, 14, 2543, 300, 55],
#  [1, 382, 12, 21, 33, 3263, 350, 653, 183, 2826],
#  [76, 2832, 109, 203, 644, 3813],
#  [1580, 5830],
#  [1, 497, 115025, 73843, 2702, 12, 21],
#  [22, 480, 60, 68],
#  [1, 207, 43, 30, 58, 18, 486, 2031, 692],
#  [25, 8, 115026, 1015],
#  [1, 7371, 3252, 467, 59],
#  [3, 51, 13, 3379, 15334, 62, 157, 5217, 498],
#  [1484, 3979, 178, 586, 2069, 198, 2703, 3675],
#  [13, 51],
#  [26660, 20, 1035, 5591, 44, 213, 1976, 83, 1571, 10, 8, 82, 115027],
#  [3, 185, 22, 115028, 11],
#  [2, 103, 4592, 32, 111],
#  [3260, 7, 525, 139],
#  [1, 55, 3869, 264, 243, 53],
#  [115029, 45, 2045, 218, 121, 78, 49, 57075],
#  [33, 498],
#  [102, 55],
#  [1, 207, 36, 311, 4, 232, 115030, 171],
#  [2080, 462, 201, 86, 390],
#  [1, 67, 179, 326],
#  [292, 102, 66, 34, 4008, 5488, 57079, 11289, 73844, 115031, 10313, 142, 7867],
#  [1, 80, 46, 973, 17017, 886, 858, 110, 390],
#  [2, 7029, 631, 73845, 115032, 33, 2138],
#  [1, 385, 55, 2, 67],
#  [115033, 173, 186, 6, 4719, 333],
#  [184, 10861, 26661, 47641, 808, 2059, 16538, 79, 6, 30],
#  [756,
#   36561,
#   115034,
#   1126,
#   73846,
#   904,
#   11,
#   10451,
#   3317,
#   115035,
#   172,
#   12092,
#   1686],
#  [1, 2, 67, 179, 326, 48, 2842, 5, 39],
#   121,
#   24,
#   42,
#   594,
#   14,
#   33,
#   6123,
#   121,
#   366,
#   618],
#  [524, 2934, 7284, 10593, 175, 4633, 1094, 3, 79, 55],
#  [1, 115065, 19299, 313, 756],
#  [62, 51, 63, 1130, 3124, 78, 11, 802, 483, 604, 73],
#  [1, 40, 946, 142, 1737, 53, 741, 10, 19, 4, 166],
#  [3, 234, 492, 4057, 663, 12733, 383, 52, 1224, 1072, 185],
#  [10, 8, 23918, 432],
#  [1, 1094, 32, 41169, 5082, 7, 115066, 4800, 4137, 99, 15, 22],
#  [1, 5464, 115067, 27, 27, 470],
#  [32, 124, 19, 255, 1532, 1506, 33, 8600, 166, 11427],
#  [1, 145, 1306, 73853, 380, 12, 21, 549, 615, 1958, 308, 1780],
#  [1, 1, 30563, 9, 478, 2, 609],
#  [1602, 23, 4, 36564, 18, 557, 3821, 7, 25, 112],
#  [1, 97, 170, 897, 141, 234, 1765],
#  [270, 2186, 498, 14993, 4704],
#  [298, 670, 17, 14, 4, 6381],
#  [1, 44, 76, 133],
#  [76, 800, 2, 4705, 158, 43, 82],
#  [1, 13, 51, 389],
#  [1, 1932, 2960, 55, 377, 5],
#  [1, 105, 11, 654, 27, 32, 367, 63],
#  [2282, 2282, 2282, 364, 333, 79],
#  [1, 855, 153, 2833],
#  [1, 46, 308, 969, 3177, 1029, 10, 7, 714, 969, 518, 73],
#  [1, 243],
#  [1, 1248, 4868, 5984, 55, 4868, 5984, 1378, 126, 2823, 2823],
#  [4362, 30],
#  [1, 1726, 1361],
#  [1, 9, 18059],
#  [15, 2419, 128, 11, 3476, 1172, 490, 962],
#  [1, 545, 17506, 300],
#  [115068, 27, 186, 75, 234, 66, 115069, 69, 889],
#  [146, 1642, 430, 408, 3373, 553, 106, 159],
#  [175, 118, 7, 11],
#  [167, 209, 356, 81, 23, 571, 57083, 3043, 15338, 181, 587],
#  [79, 2011, 25, 48, 7607, 387, 18060],
#  [1, 10, 8, 387],
#  [17020, 4634, 121, 298, 30567],
#  [1, 407, 942, 2163, 942, 284, 45, 124],
#  [1476, 8, 6482, 76],
#  [1, 87, 2816],
#  [115070, 166, 47644, 1029, 5, 81, 78, 75],
#  [1, 3483, 8119, 709, 1169],
#  [39, 242, 63, 1424, 389, 54, 2, 1685],
#  [13, 274, 115071, 514, 151, 55, 5, 2908, 9046, 1832],
#  [2478, 27, 2013, 430, 10205],
#  [1453,
#   4752,
#   1049,
#   57084,
#   1004,
#   4237,
#   161,
#   133,
#   367,
#   293,
#   977,
#   1163,
#   828,
#   1803,
#   1153],
#  [130, 171, 45, 18061, 885, 1867, 711, 856, 633, 17, 14],
#  [1, 174, 300, 69, 233],
#  [906, 19, 13, 51],
#  [1, 1350, 85, 608, 476, 670, 169, 514, 32, 438, 286, 2379, 6783],
#  [1155, 1285, 79, 71, 55, 795, 791, 876, 1058, 343, 1553, 66],
#  [2, 5402, 1453, 48, 81, 51, 4, 74, 3003, 6893, 115072, 4487],
#  [1, 253, 1334, 2, 125, 8734, 67, 1366, 425],
#  [1, 638, 115073, 3607],
#  [1338, 59, 263, 403, 37, 20, 119, 584, 25, 223],
#  [72, 57, 4, 51, 904, 323],
#  [1, 1386, 308, 388, 42, 26, 458, 450, 36, 50, 3546, 388, 17507],
#  [1, 4, 3587, 1050, 635, 73, 370, 514, 13, 168],
#  [2517, 1, 9822, 15, 891, 2388],
#  [2539, 294, 1578, 139],
#  [67, 93, 82],
#  [1760, 3, 84, 11],
#  [1, 4, 2107, 4667, 15, 420, 68, 557, 4, 1009, 1322, 7462],
#  [1, 302, 108, 221, 886, 82, 18],
#  [1, 14358, 330, 8, 33, 49, 40, 812, 840, 919, 453],
#  [1, 55, 12727, 439, 35, 610],
#  [1, 192, 62, 4, 12734, 118],
#  [1860, 84, 47, 33, 246, 449, 118],
#  [1160, 124, 178, 115074, 1299, 1160, 2, 609],
#  [18670, 1094, 166, 1175, 273, 1116, 7, 28],
#  [13, 2686],
#  [74, 667, 197, 86, 1664, 36565, 5156, 2826, 910, 17, 14],
#  [3731, 767, 156],
#  [25, 28, 267, 1713, 34, 771, 607, 343, 668, 821, 737],
#  [141, 115075, 1860, 46, 15339, 298, 22753, 246, 131, 1018, 129, 577],
#  [37, 27, 2292, 51, 663, 910, 284, 551, 550, 1218, 157],
#  [1, 195, 307, 228, 3108, 581, 393, 44, 62, 24, 228, 3108, 2751],
#  [167, 1096, 36566, 34],
#  [1, 3270, 258, 87, 4, 1759, 2762, 1735, 427, 8972, 33, 4, 15706],
#  [57, 527, 1015, 121, 527],
#  [283, 2986, 1428, 1653, 776, 2, 374, 261, 1344],
#  [1, 548, 61, 4287],
#  [1, 16, 145, 2, 2710, 25, 33234, 1601, 73, 2],
#  [1, 20, 2, 264, 2133, 18, 276, 4363, 2846, 42, 56],
#  [1, 1387, 9, 345, 2, 55, 62, 4, 349],
#  [1414, 33, 183, 288],
#  [1, 40, 55, 261, 256],
#  ...]

# %%
type(X)
# Out:
# list

# %%
new_dataset['text'][0]
# Out:
# 'tuser awww that bummer shoulda got david carr third day emojilaugh'

# %%
tokenizer_keras.word_index
# Out:
# {'tuser': 1,
#  'im': 2,
#  'go': 3,
#  'get': 4,
#  'day': 5,
#  'good': 6,
#  'work': 7,
#  'like': 8,
#  'love': 9,
#  'dont': 10,
#  'today': 11,
#  'laugh': 12,
#  'cant': 13,
#  'eye': 14,
#  'got': 15,
#  'thank': 16,
#  'tear': 17,
#  'back': 18,
#  'want': 19,
#  'miss': 20,
#  'loud': 21,
#  'one': 22,
#  'know': 23,
#  'see': 24,
#  'feel': 25,
#  'think': 26,
#  'realli': 27,
#  'well': 28,
#  'hope': 29,
#  'night': 30,
#  'watch': 31,
#  'need': 32,
#  'still': 33,
#  'make': 34,
#  'new': 35,
#  'amp': 36,
#  'home': 37,
#  'look': 38,
#  'come': 39,
#  'oh': 40,
#  '2': 41,
#  'much': 42,
#  'last': 43,
#  'twitter': 44,
#  'morn': 45,
#  'great': 46,
#  'tomorrow': 47,
#  'wish': 48,
#  'wait': 49,
#  'ill': 50,
#  'sleep': 51,
#  'that': 52,
#  'haha': 53,
#  'way': 54,
#  'sad': 55,
#  'fun': 56,
#  'tri': 57,
#  'right': 58,
#  'week': 59,
#  'follow': 60,
#  'happi': 61,
#  'didnt': 62,
#  'bad': 63,
#  'would': 64,
#  'friend': 65,
#  'thing': 66,
#  'sorri': 67,
#  'tonight': 68,
#  'say': 69,
#  'take': 70,
#  'nice': 71,
#  'gonna': 72,
#  'though': 73,
#  'ive': 74,
#  'better': 75,
#  'hate': 76,
#  'even': 77,
#  'start': 78,
#  'bed': 79,
#  'yeah': 80,
#  'could': 81,
#  'tweet': 82,
#  'peopl': 83,
#  'school': 84,
#  'show': 85,
#  'hour': 86,
#  'your': 87,
#  'guy': 88,
#  'play': 89,
#  'weekend': 90,
#  'hey': 91,
#  'final': 92,
#  'next': 93,
#  'use': 94,
#  'soon': 95,
#  'awesom': 96,
#  'ye': 97,
#  'let': 98,
#  'never': 99,
#  'best': 100,
#  'long': 101,
#  'littl': 102,
#  'tire': 103,
#  'plea': 104,
#  'rain': 105,
#  'first': 106,
#  'wanna': 107,
#  'everyon': 108,
#  'movi': 109,
#  'year': 110,
#  'life': 111,
#  'sick': 112,
#  '4': 113,
#  'find': 114,
#  'keep': 115,
#  'ok': 116,
#  'sure': 117,
#  'suck': 118,
#  'call': 119,
#  'girl': 120,
#  'wont': 121,
#  '3': 122,
#  'talk': 123,
#  'help': 124,
#  'done': 125,
#  'head': 126,
#  'alway': 127,
#  'bore': 128,
#  'alreadi': 129,
#  'anoth': 130,
#  'lot': 131,
#  'cool': 132,
#  'u': 133,
#  'someth': 134,
#  'live': 135,
#  'eat': 136,
#  'phone': 137,
#  'leav': 138,
#  'hurt': 139,
#  'readi': 140,
#  'read': 141,
#  'made': 142,
#  'enjoy': 143,
#  'x': 144,
#  'man': 145,
#  'yay': 146,
#  'went': 147,
#  'ur': 148,
#  'song': 149,
#  'doesnt': 150,
#  'hous': 151,
#  'yet': 152,
#  'sound': 153,
#  'thought': 154,
#  'pretti': 155,
#  'ever': 156,
#  'finish': 157,
#  'excit': 158,
#  'game': 159,
#  'away': 160,
#  'tell': 161,
#  'mayb': 162,
#  'amaz': 163,
#  'summer': 164,
#  'guess': 165,
#  'old': 166,
#  'omg': 167,
#  'listen': 168,
#  'mean': 169,
#  'someon': 170,
#  'earli': 171,
#  'damn': 172,
#  'give': 173,
#  'left': 174,
#  'lost': 175,
#  'bit': 176,
#  'check': 177,
#  'babi': 178,
#  'hear': 179,
#  'big': 180,
#  'lt3': 181,
#  'parti': 182,
#  'end': 183,
#  'hot': 184,
#  'late': 185,
#  'noth': 186,
#  'later': 187,
#  'havent': 188,
#  'kid': 189,
#  'actual': 190,
#  'birthday': 191,
#  'wow': 192,
#  'glad': 193,
#  'happen': 194,
#  'also': 195,
#  'pic': 196,
#  '1': 197,
#  'stop': 198,
#  'weather': 199,
#  'sun': 200,
#  'two': 201,
#  'wonder': 202,
#  'put': 203,
#  'stuff': 204,
#  'ya': 205,
#  'saw': 206,
#  'mom': 207,
#  'isnt': 208,
#  'exam': 209,
#  'n': 210,
#  'stay': 211,
#  'might': 212,
#  'fuck': 213,
#  'said': 214,
#  'hard': 215,
#  'run': 216,
#  'he': 217,
#  'car': 218,
#  'god': 219,
#  'sinc': 220,
#  'yesterday': 221,
#  'meet': 222,
#  'world': 223,
#  'music': 224,
#  'ugh': 225,
#  'job': 226,
#  'beauti': 227,
#  'updat': 228,
#  'mani': 229,
#  'id': 230,
#  'gotta': 231,
#  'around': 232,
#  'hi': 233,
#  'post': 234,
#  'sunday': 235,
#  'seem': 236,
#  'friday': 237,
#  'video': 238,
#  'monday': 239,
#  'found': 240,
#  'luck': 241,
#  'cold': 242,
#  'cri': 243,
#  'move': 244,
#  'emojiwink': 245,
#  'book': 246,
#  'die': 247,
#  'must': 248,
#  'time': 249,
#  'what': 250,
#  'gone': 251,
#  'busi': 252,
#  'may': 253,
#  'aww': 254,
#  'buy': 255,
#  'boy': 256,
#  'anyth': 257,
#  'least': 258,
#  'woke': 259,
#  '5': 260,
#  'poor': 261,
#  'plan': 262,
#  'till': 263,
#  'total': 264,
#  'famili': 265,
#  'shop': 266,
#  'stupid': 267,
#  'studi': 268,
#  'hair': 269,
#  'almost': 270,
#  'cute': 271,
#  'food': 272,
#  'iphon': 273,
#  'believ': 274,
#  'okay': 275,
#  'tho': 276,
#  'lunch': 277,
#  'far': 278,
#  'welcom': 279,
#  'pictur': 280,
#  'drink': 281,
#  'win': 282,
#  'there': 283,
#  'free': 284,
#  'chang': 285,
#  'month': 286,
#  'caus': 287,
#  'place': 288,
#  'everyth': 289,
#  'sweet': 290,
#  'dinner': 291,
#  'funni': 292,
#  'anyon': 293,
#  'class': 294,
#  'she': 295,
#  'shit': 296,
#  'forward': 297,
#  'turn': 298,
#  'sit': 299,
#  'without': 300,
#  'drive': 301,
#  'ask': 302,
#  'mine': 303,
#  'walk': 304,
#  'name': 305,
#  'r': 306,
#  'send': 307,
#  'idea': 308,
#  'dream': 309,
#  'write': 310,
#  'dad': 311,
#  'real': 312,
#  'wasnt': 313,
#  'outsid': 314,
#  'clean': 315,
#  'enough': 316,
#  'hahaha': 317,
#  'coffe': 318,
#  'everi': 319,
#  'wrong': 320,
#  'wake': 321,
#  'probabl': 322,
#  'room': 323,
#  'anymor': 324,
#  'w': 325,
#  'dog': 326,
#  'couldnt': 327,
#  'saturday': 328,
#  'fan': 329,
#  'money': 330,
#  'hell': 331,
#  'tv': 332,
#  'minut': 333,
#  'person': 334,
#  'xx': 335,
#  'sooo': 336,
#  'el': 337,
#  'ha': 338,
#  'hit': 339,
#  'rememb': 340,
#  'aw': 341,
#  'headach': 342,
#  'whole': 343,
#  'came': 344,
#  'p': 345,
#  'break': 346,
#  'brother': 347,
#  'seen': 348,
#  'hang': 349,
#  'face': 350,
#  'fail': 351,
#  'repli': 352,
#  'train': 353,
#  'beach': 354,
#  'rock': 355,
#  'kill': 356,
#  'blog': 357,
#  'kinda': 358,
#  'open': 359,
#  'rest': 360,
#  'mother': 361,
#  'pain': 362,
#  'close': 363,
#  '10': 364,
#  'crazi': 365,
#  'care': 366,
#  'quit': 367,
#  'word': 368,
#  'took': 369,
#  'comput': 370,
#  'super': 371,
#  'text': 372,
#  'hello': 373,
#  'worri': 374,
#  'theyr': 375,
#  'abl': 376,
#  'news': 377,
#  'email': 378,
#  'half': 379,
#  'anyway': 380,
#  'forgot': 381,
#  'true': 382,
#  'problem': 383,
#  'trip': 384,
#  'awww': 385,
#  'part': 386,
#  'goodnight': 387,
#  'bring': 388,
#  'either': 389,
#  'ago': 390,
#  'b': 391,
#  'offic': 392,
#  'photo': 393,
#  'kind': 394,
#  'heart': 395,
#  'pay': 396,
#  'link': 397,
#  'full': 398,
#  'soo': 399,
#  'mind': 400,
#  'hug': 401,
#  'danc': 402,
#  'sister': 403,
#  'ah': 404,
#  'cuz': 405,
#  'internet': 406,
#  'stuck': 407,
#  'boo': 408,
#  'fall': 409,
#  'alon': 410,
#  'heard': 411,
#  '6': 412,
#  'cours': 413,
#  'ticket': 414,
#  'pick': 415,
#  'test': 416,
#  'sometim': 417,
#  'hehe': 418,
#  'site': 419,
#  'set': 420,
#  'learn': 421,
#  'pas': 422,
#  'la': 423,
#  'vote': 424,
#  'interest': 425,
#  'add': 426,
#  'moment': 427,
#  'concert': 428,
#  'visit': 429,
#  'season': 430,
#  'onlin': 431,
#  'shower': 432,
#  'hand': 433,
#  'told': 434,
#  'fine': 435,
#  'dude': 436,
#  'awak': 437,
#  'fix': 438,
#  'favorit': 439,
#  'goe': 440,
#  'suppos': 441,
#  'breakfast': 442,
#  'til': 443,
#  'cat': 444,
#  'wear': 445,
#  'sunni': 446,
#  'ice': 447,
#  'catch': 448,
#  'broke': 449,
#  'spend': 450,
#  'bought': 451,
#  'facebook': 452,
#  'serious': 453,
#  'smile': 454,
#  'as': 455,
#  'cut': 456,
#  'pack': 457,
#  'youll': 458,
#  'wed': 459,
#  'a': 460,
#  'lucki': 461,
#  'asleep': 462,
#  'crap': 463,
#  'june': 464,
#  'reason': 465,
#  'ride': 466,
#  '8': 467,
#  'sign': 468,
#  'agre': 469,
#  'mad': 470,
#  'hungri': 471,
#  'definit': 472,
#  '30': 473,
#  'afternoon': 474,
#  'instead': 475,
#  'red': 476,
#  'xd': 477,
#  'ladi': 478,
#  'jealou': 479,
#  'le': 480,
#  'tea': 481,
#  '100': 482,
#  'sore': 483,
#  'bout': 484,
#  'join': 485,
#  'figur': 486,
#  'album': 487,
#  'second': 488,
#  'citi': 489,
#  'page': 490,
#  'nap': 491,
#  'stori': 492,
#  'messag': 493,
#  'top': 494,
#  'bye': 495,
#  'graduat': 496,
#  'yea': 497,
#  'homework': 498,
#  'soooo': 499,
#  'bday': 500,
#  '7': 501,
#  'tour': 502,
#  'sing': 503,
#  'togeth': 504,
#  'list': 505,
#  'coupl': 506,
#  'high': 507,
#  'holiday': 508,
#  'congrat': 509,
#  'laptop': 510,
#  'award': 511,
#  'park': 512,
#  'date': 513,
#  'dead': 514,
#  'save': 515,
#  'goin': 516,
#  'water': 517,
#  'store': 518,
#  'revis': 519,
#  'point': 520,
#  'drop': 521,
#  'dear': 522,
#  'star': 523,
#  'complet': 524,
#  'foot': 525,
#  'possibl': 526,
#  'download': 527,
#  'dress': 528,
#  'sigh': 529,
#  'ppl': 530,
#  'relax': 531,
#  'youtub': 532,
#  'ipod': 533,
#  'account': 534,
#  'answer': 535,
#  'perfect': 536,
#  'share': 537,
#  'short': 538,
#  'forev': 539,
#  '12': 540,
#  'wouldnt': 541,
#  'church': 542,
#  'annoy': 543,
#  'side': 544,
#  'cook': 545,
#  'decid': 546,
#  'offici': 547,
#  'arent': 548,
#  'realiz': 549,
#  'town': 550,
#  'line': 551,
#  'nite': 552,
#  'lose': 553,
#  'scare': 554,
#  'forget': 555,
#  'weird': 556,
#  'order': 557,
#  'lil': 558,
#  'f': 559,
#  'mood': 560,
#  'yall': 561,
#  'gym': 562,
#  'chat': 563,
#  'min': 564,
#  'understand': 565,
#  'math': 566,
#  'mum': 567,
#  'cream': 568,
#  'unfortun': 569,
#  'air': 570,
#  'differ': 571,
#  'fb': 572,
#  'ate': 573,
#  'english': 574,
#  'past': 575,
#  'episod': 576,
#  'knew': 577,
#  'usual': 578,
#  'chocol': 579,
#  'fli': 580,
#  'upload': 581,
#  'pool': 582,
#  'comment': 583,
#  'worst': 584,
#  'band': 585,
#  'aint': 586,
#  'gt': 587,
#  'worth': 588,
#  'kick': 589,
#  'support': 590,
#  'window': 591,
#  'fast': 592,
#  'horribl': 593,
#  'london': 594,
#  'chanc': 595,
#  'load': 596,
#  'ahh': 597,
#  'parent': 598,
#  'flight': 599,
#  'broken': 600,
#  'da': 601,
#  '20': 602,
#  'cheer': 603,
#  'throat': 604,
#  'question': 605,
#  'via': 606,
#  'upset': 607,
#  'three': 608,
#  'sleepi': 609,
#  'team': 610,
#  'mr': 611,
#  'sat': 612,
#  '1st': 613,
#  'xxx': 614,
#  'sent': 615,
#  'black': 616,
#  'card': 617,
#  'bless': 618,
#  'special': 619,
#  'gave': 620,
#  'followfriday': 621,
#  'yep': 622,
#  'sunshin': 623,
#  'beat': 624,
#  'depress': 625,
#  'age': 626,
#  'number': 627,
#  'slow': 628,
#  'finger': 629,
#  'ad': 630,
#  'mac': 631,
#  'bet': 632,
#  'leg': 633,
#  'colleg': 634,
#  'record': 635,
#  'jona': 636,
#  'green': 637,
#  'fell': 638,
#  'websit': 639,
#  'project': 640,
#  'app': 641,
#  'tuesday': 642,
#  'cake': 643,
#  'em': 644,
#  'appar': 645,
#  'wors': 646,
#  'paper': 647,
#  'beer': 648,
#  'rather': 649,
#  'moon': 650,
#  'film': 651,
#  'longer': 652,
#  'warm': 653,
#  'garden': 654,
#  'power': 655,
#  'c': 656,
#  'hmm': 657,
#  'huge': 658,
#  'vacat': 659,
#  'cannot': 660,
#  'easi': 661,
#  'blue': 662,
#  'due': 663,
#  'fair': 664,
#  'youv': 665,
#  'mess': 666,
#  'spent': 667,
#  'bodi': 668,
#  'freak': 669,
#  'light': 670,
#  'disappoint': 671,
#  'shoe': 672,
#  'v': 673,
#  'juli': 674,
#  'lay': 675,
#  'celebr': 676,
#  'quot': 677,
#  'miley': 678,
#  'safe': 679,
#  'mtv': 680,
#  'sim': 681,
#  'rip': 682,
#  'roll': 683,
#  'bike': 684,
#  'how': 685,
#  'cancel': 686,
#  'nope': 687,
#  'bu': 688,
#  'shame': 689,
#  'chill': 690,
#  'googl': 691,
#  'burn': 692,
#  'cousin': 693,
#  'lazi': 694,
#  'co': 695,
#  'flu': 696,
#  '9': 697,
#  'plu': 698,
#  'stomach': 699,
#  'earlier': 700,
#  'voic': 701,
#  'absolut': 702,
#  'woman': 703,
#  'remind': 704,
#  'hold': 705,
#  'thursday': 706,
#  'stress': 707,
#  'white': 708,
#  'babe': 709,
#  'swim': 710,
#  'manag': 711,
#  'appreci': 712,
#  'touch': 713,
#  'uk': 714,
#  'camera': 715,
#  'shot': 716,
#  'met': 717,
#  'slept': 718,
#  'camp': 719,
#  'sort': 720,
#  'david': 721,
#  'current': 722,
#  'cd': 723,
#  'son': 724,
#  'crash': 725,
#  'bum': 726,
#  'except': 727,
#  'insid': 728,
#  'boyfriend': 729,
#  'lie': 730,
#  'pray': 731,
#  'ahhh': 732,
#  'piss': 733,
#  'wit': 734,
#  'tom': 735,
#  'appl': 736,
#  'shoot': 737,
#  'box': 738,
#  'especi': 739,
#  'sadli': 740,
#  'idk': 741,
#  'type': 742,
#  'dm': 743,
#  'fight': 744,
#  'cover': 745,
#  'block': 746,
#  'meant': 747,
#  '15': 748,
#  'father': 749,
#  'arriv': 750,
#  'myspac': 751,
#  'terribl': 752,
#  'present': 753,
#  'case': 754,
#  'airport': 755,
#  'invit': 756,
#  'bbq': 757,
#  'bro': 758,
#  'itll': 759,
#  'yummi': 760,
#  'pizza': 761,
#  'note': 762,
#  'expect': 763,
#  'luv': 764,
#  'servic': 765,
#  'road': 766,
#  'confus': 767,
#  'raini': 768,
#  'hospit': 769,
#  'bitch': 770,
#  'tummi': 771,
#  'si': 772,
#  'deal': 773,
#  'small': 774,
#  'interview': 775,
#  'count': 776,
#  'chicken': 777,
#  'club': 778,
#  'fit': 779,
#  'shirt': 780,
#  'tast': 781,
#  '2day': 782,
#  'smell': 783,
#  'felt': 784,
#  'notic': 785,
#  'cloth': 786,
#  'mention': 787,
#  'doctor': 788,
#  'shall': 789,
#  'hr': 790,
#  'hubbi': 791,
#  'proud': 792,
#  'hill': 793,
#  'ear': 794,
#  'lone': 795,
#  'cup': 796,
#  'speak': 797,
#  'radio': 798,
#  'design': 799,
#  'fact': 800,
#  'goodby': 801,
#  'begin': 802,
#  'stand': 803,
#  'storm': 804,
#  'addict': 805,
#  'search': 806,
#  'wine': 807,
#  'pull': 808,
#  'gorgeou': 809,
#  'exactli': 810,
#  'issu': 811,
#  'surpris': 812,
#  'wash': 813,
#  'wednesday': 814,
#  'twilight': 815,
#  'alright': 816,
#  'practic': 817,
#  'front': 818,
#  'yup': 819,
#  'glass': 820,
#  'ach': 821,
#  'near': 822,
#  'product': 823,
#  'lame': 824,
#  'connect': 825,
#  'laker': 826,
#  'dvd': 827,
#  'compani': 828,
#  'taken': 829,
#  'french': 830,
#  'bag': 831,
#  'becom': 832,
#  'peac': 833,
#  'tan': 834,
#  'xoxo': 835,
#  'mate': 836,
#  'apart': 837,
#  'woo': 838,
#  'bar': 839,
#  'state': 840,
#  'ju': 841,
#  'yr': 842,
#  'scari': 843,
#  'event': 844,
#  '2nd': 845,
#  'joke': 846,
#  'memori': 847,
#  'exhaust': 848,
#  'bc': 849,
#  'behind': 850,
#  'paint': 851,
#  'normal': 852,
#  'everybodi': 853,
#  'version': 854,
#  'ouch': 855,
#  'cross': 856,
#  'whatev': 857,
#  'sold': 858,
#  'drunk': 859,
#  'guitar': 860,
#  'round': 861,
#  'return': 862,
#  'gettin': 863,
#  'prob': 864,
#  'random': 865,
#  'travel': 866,
#  'sell': 867,
#  'mommi': 868,
#  'allow': 869,
#  'matter': 870,
#  'plane': 871,
#  'daughter': 872,
#  'child': 873,
#  'releas': 874,
#  'door': 875,
#  'puppi': 876,
#  'promis': 877,
#  'yo': 878,
#  'ball': 879,
#  'arm': 880,
#  'mile': 881,
#  'fantast': 882,
#  'along': 883,
#  'wife': 884,
#  'although': 885,
#  'singl': 886,
#  'hahah': 887,
#  'art': 888,
#  'alot': 889,
#  'vega': 890,
#  'fire': 891,
#  'ruin': 892,
#  'sale': 893,
#  'ff': 894,
#  'magic': 895,
#  'group': 896,
#  'hasnt': 897,
#  'dark': 898,
#  'floor': 899,
#  '11': 900,
#  'countri': 901,
#  'fish': 902,
#  'hangov': 903,
#  'hotel': 904,
#  'cooki': 905,
#  'l': 906,
#  'wat': 907,
#  'bug': 908,
#  'ahead': 909,
#  'wast': 910,
#  'act': 911,
#  'track': 912,
#  'pop': 913,
#  'inde': 914,
#  'perform': 915,
#  'deserv': 916,
#  'vip': 917,
#  'screen': 918,
#  'hmmm': 919,
#  'histori': 920,
#  'web': 921,
#  'buddi': 922,
#  'ohh': 923,
#  'profil': 924,
#  'fri': 925,
#  'eh': 926,
#  'instal': 927,
#  'bird': 928,
#  'death': 929,
#  'hun': 930,
#  'other': 931,
#  'nick': 932,
#  'huh': 933,
#  'pc': 934,
#  'bloodi': 935,
#  'race': 936,
#  'extra': 937,
#  'grow': 938,
#  'fml': 939,
#  'throw': 940,
#  'heat': 941,
#  'traffic': 942,
#  'nobodi': 943,
#  'who': 944,
#  'delet': 945,
#  'gosh': 946,
#  'street': 947,
#  'ran': 948,
#  'e': 949,
#  'watchin': 950,
#  'sexi': 951,
#  'quick': 952,
#  'fill': 953,
#  'nose': 954,
#  'prepar': 955,
#  'nail': 956,
#  'troubl': 957,
#  'recommend': 958,
#  'gut': 959,
#  'posit': 960,
#  'mail': 961,
#  'daddi': 962,
#  'caught': 963,
#  'fat': 964,
#  'chees': 965,
#  'twit': 966,
#  'cough': 967,
#  'seriou': 968,
#  'itun': 969,
#  'nearli': 970,
#  'gay': 971,
#  'bb': 972,
#  'vid': 973,
#  'low': 974,
#  'somewher': 975,
#  'angel': 976,
#  'suggest': 977,
#  'result': 978,
#  'na': 979,
#  'coz': 980,
#  'land': 981,
#  'blood': 982,
#  'yum': 983,
#  'view': 984,
#  'pink': 985,
#  'shouldnt': 986,
#  'mall': 987,
#  'edit': 988,
#  'def': 989,
#  'congratul': 990,
#  'fav': 991,
#  'chillin': 992,
#  'market': 993,
#  'inspir': 994,
#  'dunno': 995,
#  'stick': 996,
#  'ooh': 997,
#  'shine': 998,
#  'major': 999,
#  'choic': 1000,
#  ...}

# %%
new_dataset['target'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Series name: target
# Non-Null Count    Dtype
# --------------    -----
# 1600000 non-null  int64
# dtypes: int64(1)
# memory usage: 12.2 MB

# %%
y=pd.get_dummies(new_dataset['target']).values
y
# Out:
# array([[ True, False],
#        [ True, False],
#        [ True, False],
#        ...,
#        [False,  True],
#        [False,  True],
#        [False,  True]])

# %%
y[:2]
# Out:
# array([[ True, False],
#        [ True, False]])

# %% [markdown]
# ## 4.Pad Sequnce

# %%
X = pad_sequences(X)

# %% [markdown]
# ## 5.Split Data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1120000, 38), (480000, 38), (1120000, 2), (480000, 2))

# %%
valid_size = 240000
X_valid = X_test[-valid_size:]
y_valid = y_test[-valid_size:]
X_test = X_test[:-valid_size]
y_test = y_test[:-valid_size]

# %%
X_test.shape
# Out:
# (240000, 38)

# %%
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, Dropout, SimpleRNN, SpatialDropout1D,GRU, Bidirectional
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import EarlyStopping

# %% [markdown]
# ## 6.Connect with TPU

# %%
embed_dim = 128

# %%
# To detect the TPU
import tensorflow as tf
tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
print("All devices: ", tf.config.list_logical_devices('TPU'))

tpu_statergy = tf.distribute.TPUStrategy(tpu)

# with tpu_statergy.scope():
#   model = Sequential()
#   model.add(Embedding(max_features, embed_dim,input_length = X.shape[1]))
#   model.add(SpatialDropout1D(0.4))
#   model.add(SimpleRNN(196, dropout=0.2, recurrent_dropout=0.2))
#   model.add(Dense(2,activation='softmax', kernel_regularizer=l2(0.001)))

#   model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
#   print(model.summary())
# Out:
# All devices:  [LogicalDevice(name='/device:TPU:0', device_type='TPU'), LogicalDevice(name='/device:TPU:1', device_type='TPU'), LogicalDevice(name='/device:TPU:2', device_type='TPU'), LogicalDevice(name='/device:TPU:3', device_type='TPU'), LogicalDevice(name='/device:TPU:4', device_type='TPU'), LogicalDevice(name='/device:TPU:5', device_type='TPU'), LogicalDevice(name='/device:TPU:6', device_type='TPU'), LogicalDevice(name='/device:TPU:7', device_type='TPU')]

# %% [markdown]
# ##7.Build the Model

# %% [markdown]
# ###7.1 Simple RNN Model

# %%
with tpu_statergy.scope():
  model_rnn = Sequential()
  model_rnn.add(Embedding(max_features, embed_dim,input_length = X.shape[1]))
  model_rnn.add(SpatialDropout1D(0.4))
  model_rnn.add(Bidirectional(SimpleRNN(196, dropout=0.2, recurrent_dropout=0.2, return_sequences = True)))
  model_rnn.add(Bidirectional(SimpleRNN(196, dropout=0.2, recurrent_dropout=0.2)))
  model_rnn.add(Dense(2,activation='softmax', kernel_regularizer=l2(0.001)))

  model_rnn.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
  print(model_rnn.summary())


# Compile RNN Model :
from keras import callbacks

earlyStopping = callbacks.EarlyStopping(monitor='val_loss',
                                        patience=5,
                                        mode='min',
                                        restore_best_weights=True)

model_rnn.fit(X_train, y_train, epochs = 20,
          batch_size=1024,
          verbose = 1,
          validation_data=(X_valid, y_valid),
          callbacks=[earlyStopping])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 38, 128)           50713088
#
#  spatial_dropout1d_3 (Spati  (None, 38, 128)           0
#  alDropout1D)
#
#  bidirectional_2 (Bidirecti  (None, 38, 392)           127400
#  onal)
#
#  bidirectional_3 (Bidirecti  (None, 392)               230888
#  onal)
#
#  dense (Dense)               (None, 2)                 786
#
# =================================================================
# Total params: 51072162 (194.82 MB)
# Trainable params: 51072162 (194.82 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/20
# 1094/1094 [==============================] - 64s 46ms/step - loss: 0.5070 - accuracy: 0.7492 - val_loss: 0.4603 - val_accuracy: 0.7849
# Epoch 2/20
# 1094/1094 [==============================] - 40s 36ms/step - loss: 0.4402 - accuracy: 0.7966 - val_loss: 0.4536 - val_accuracy: 0.7870
# Epoch 3/20
# 1094/1094 [==============================] - 40s 36ms/step - loss: 0.4108 - accuracy: 0.8138 - val_loss: 0.4558 - val_accuracy: 0.7854
# Epoch 4/20
# 1094/1094 [==============================] - 40s 36ms/step - loss: 0.3896 - accuracy: 0.8255 - val_loss: 0.4718 - val_accuracy: 0.7827
# Epoch 5/20
# 1094/1094 [==============================] - 40s 36ms/step - loss: 0.3767 - accuracy: 0.8325 - val_loss: 0.4713 - val_accuracy: 0.7817
# Epoch 6/20
# 1094/1094 [==============================] - 40s 36ms/step - loss: 0.3620 - accuracy: 0.8395 - val_loss: 0.4835 - val_accuracy: 0.7801
# Epoch 7/20
# 1094/1094 [==============================] - 43s 40ms/step - loss: 0.3524 - accuracy: 0.8442 - val_loss: 0.4947 - val_accuracy: 0.7776

# %% [markdown]
# ###7.2 LSTM RNN Model

# %%
with tpu_statergy.scope():
  model_lstm = Sequential()
  model_lstm.add(Embedding(max_features, embed_dim,input_length = X.shape[1]))
  model_lstm.add(SpatialDropout1D(0.4))
  model_lstm.add(Bidirectional(LSTM(196, dropout=0.2, recurrent_dropout=0.2, return_sequences=True)))
  model_lstm.add(Bidirectional(LSTM(196, dropout=0.2, recurrent_dropout=0.2)))
  model_lstm.add(Dense(2,activation='softmax', kernel_regularizer=l2(0.001)))

  model_lstm.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
  print(model_lstm.summary())


# Compile LSTM Model :
from keras import callbacks

earlyStopping = callbacks.EarlyStopping(monitor='val_loss',
                                        patience=5,
                                        mode='min',
                                        restore_best_weights=True)

model_lstm.fit(X_train, y_train, epochs = 20,
          batch_size=1024,
          verbose = 1,
          validation_data=(X_valid, y_valid),
          callbacks=[earlyStopping])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 38, 128)           50713088
#
#  spatial_dropout1d_4 (Spati  (None, 38, 128)           0
#  alDropout1D)
#
#  bidirectional_4 (Bidirecti  (None, 38, 392)           509600
#  onal)
#
#  bidirectional_5 (Bidirecti  (None, 392)               923552
#  onal)
#
#  dense_1 (Dense)             (None, 2)                 786
#
# =================================================================
# Total params: 52147026 (198.93 MB)
# Trainable params: 52147026 (198.93 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/20
# 1094/1094 [==============================] - 143s 108ms/step - loss: 0.4741 - accuracy: 0.7725 - val_loss: 0.4489 - val_accuracy: 0.7886
# Epoch 2/20
# 1094/1094 [==============================] - 99s 90ms/step - loss: 0.4185 - accuracy: 0.8069 - val_loss: 0.4423 - val_accuracy: 0.7926
# Epoch 3/20
# 1094/1094 [==============================] - 98s 90ms/step - loss: 0.3826 - accuracy: 0.8270 - val_loss: 0.4493 - val_accuracy: 0.7901
# Epoch 4/20
# 1094/1094 [==============================] - 98s 90ms/step - loss: 0.3538 - accuracy: 0.8422 - val_loss: 0.4616 - val_accuracy: 0.7888
# Epoch 5/20
# 1094/1094 [==============================] - 99s 90ms/step - loss: 0.3268 - accuracy: 0.8548 - val_loss: 0.4843 - val_accuracy: 0.7867
# Epoch 6/20
# 1094/1094 [==============================] - 98s 90ms/step - loss: 0.3030 - accuracy: 0.8648 - val_loss: 0.5195 - val_accuracy: 0.7854
# Epoch 7/20
# 1094/1094 [==============================] - 102s 93ms/step - loss: 0.2870 - accuracy: 0.8715 - val_loss: 0.5370 - val_accuracy: 0.7861

# %% [markdown]
# ###7.3 GRU RNN Model

# %%
with tpu_statergy.scope():
  model_GRU = Sequential()
  model_GRU.add(Embedding(max_features, embed_dim,input_length = X.shape[1]))
  model_GRU.add(SpatialDropout1D(0.4))
  model_GRU.add(Bidirectional(GRU(196, dropout=0.2, recurrent_dropout=0.2, return_sequences=True)))
  model_GRU.add(Bidirectional(GRU(196, dropout=0.2, recurrent_dropout=0.2)))
  model_GRU.add(Dense(2,activation='softmax', kernel_regularizer=l2(0.001)))

  model_GRU.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
  print(model_GRU.summary())



# Compile GRU Model :
from keras import callbacks

earlyStopping = callbacks.EarlyStopping(monitor='val_loss',
                                        patience=5,
                                        mode='min',
                                        restore_best_weights=True)

model_GRU.fit(X_train, y_train, epochs = 20,
          batch_size=1024,
          verbose = 1,
          validation_data=(X_valid, y_valid),
          callbacks=[earlyStopping])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 38, 128)           50713088
#
#  spatial_dropout1d_5 (Spati  (None, 38, 128)           0
#  alDropout1D)
#
#  bidirectional_6 (Bidirecti  (None, 38, 392)           383376
#  onal)
#
#  bidirectional_7 (Bidirecti  (None, 392)               693840
#  onal)
#
#  dense_2 (Dense)             (None, 2)                 786
#
# =================================================================
# Total params: 51791090 (197.57 MB)
# Trainable params: 51791090 (197.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/20
# 1094/1094 [==============================] - 135s 100ms/step - loss: 0.4713 - accuracy: 0.7741 - val_loss: 0.4418 - val_accuracy: 0.7928
# Epoch 2/20
# 1094/1094 [==============================] - 92s 84ms/step - loss: 0.4137 - accuracy: 0.8102 - val_loss: 0.4400 - val_accuracy: 0.7939
# Epoch 3/20
# 1094/1094 [==============================] - 91s 83ms/step - loss: 0.3772 - accuracy: 0.8308 - val_loss: 0.4481 - val_accuracy: 0.7913
# Epoch 4/20
# 1094/1094 [==============================] - 91s 84ms/step - loss: 0.3459 - accuracy: 0.8475 - val_loss: 0.4682 - val_accuracy: 0.7888
# Epoch 5/20
# 1094/1094 [==============================] - 91s 83ms/step - loss: 0.3152 - accuracy: 0.8608 - val_loss: 0.4921 - val_accuracy: 0.7848
# Epoch 6/20
# 1094/1094 [==============================] - 91s 83ms/step - loss: 0.2940 - accuracy: 0.8694 - val_loss: 0.5250 - val_accuracy: 0.7864
# Epoch 7/20
# 1094/1094 [==============================] - 95s 86ms/step - loss: 0.2803 - accuracy: 0.8751 - val_loss: 0.5460 - val_accuracy: 0.7848

# %%
X_test[0].size
# Out:
# 38

# %%
pred = model_rnn.predict(X_test)
# Out:
# 7500/7500 [==============================] - 40s 5ms/step

# %%
pred
# Out:
# array([[0.34587303, 0.65412694],
#        [0.18184012, 0.8181599 ],
#        [0.09331241, 0.90668756],
#        ...,
#        [0.46880502, 0.531195  ],
#        [0.05761576, 0.9423843 ],
#        [0.71405286, 0.2859471 ]], dtype=float32)

# %% [markdown]
# ## 8.Prediction

# %%
def predict_sentiment_rnn(tweet):
  '''
  Predicts the sentiment of the tweet using the trained RNN model.

  Agrs:
      tweet = The tweet as a string.

  Return:
      'Happy' if the predicted sentiment is positive, 'Unhappy' otherwise

  '''

  # Preprocess to tweet

  tweet_seq = tokenizer_keras.texts_to_sequences([tweet])
  # Use tweet_pad which has been padded to match the expected shape of the model
  tweet_pad = pad_sequences(tweet_seq, maxlen=X.shape[1]) # X.shape[1] represents the maxlen used during training

  # Predict sentiment using the RNN Model
  # Use tweet_pad as an input to the predict function instead of tweet_seq
  prediction = model_GRU.predict(tweet_pad)[0]
  sentiment_label = np.argmax(prediction)

  # Return the sentiment label
  if sentiment_label == 1:
    return 'Happy'
  else:
    return 'Unhappy'

  # Example usage:
new_tweets = [
    "This is a great day ! I' am so happy.",
    "I'm feeling really down today.",
    "This product is amazing"
]

for tweet in new_tweets:
  predicted_sentiment = predict_sentiment_rnn(tweet)
  print(f"Tweet: '{tweet}'\nPredicted Sentiment: {predicted_sentiment}\n")
# Out:
# 1/1 [==============================] - 1s 1s/step
# Tweet: 'This is a great day ! I' am so happy.'
# Predicted Sentiment: Happy
#
# 1/1 [==============================] - 0s 416ms/step
# Tweet: 'I'm feeling really down today.'
# Predicted Sentiment: Unhappy
#
# 1/1 [==============================] - 0s 433ms/step
# Tweet: 'This product is amazing'
# Predicted Sentiment: Happy
